# %% [markdown]
# ## About the sheet:
#
# 1. Creates two retreivers, first retreiver a standard one. Creates the semantic embeddings, picks top k chunks.
#
# 2. Second retreiver, enhanced descriptions, embedding generation with BM25 and semantically. Reranking the chunks to pick top k.

# %%
import boto3
import numpy as np
import json
import pandas as pd
import time
import os
from sentence_transformers import SentenceTransformer
import faiss
import hashlib
from rank_bm25 import BM25Okapi
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle
from sentence_transformers import CrossEncoder
import requests
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("Imputed_decription.csv").drop(["Unnamed: 0.1", "Unnamed: 0"], axis = 1)
df["categories"] = np.where(df["categories"].isna(), "Unknown", df["categories"])
df["rating"] = np.where(df["rating"].isna(), 0, df["rating"])
df["review_count"] = np.where(df["review_count"].isna(), 0, df["review_count"])
df["price"] = np.where(df["price"].isna(), "$", df["price"])

# %%
QnA = pd.read_csv("QnA.csv")

# %%
from dotenv import load_dotenv
import os


load_dotenv("Credentials")  

bedrock_client = boto3.client(
    service_name = "bedrock-runtime",
    region_name="us-east-2",
    aws_access_key_id = os.getenv("aws_access_key_id"), 
    aws_secret_access_key = os.getenv("aws_secret_access_key")
)

# %%
def add_restaurant_id(df):

    address_cols = ['address1', 'city', 'state', 'zip_code', 'country']
    
    df[address_cols] = df[address_cols].fillna('').astype(str)
    df['address_fingerprint'] = df[address_cols].apply(lambda x: '|'.join(x), axis=1)
    
    df['restaurant_id'] = df.apply(
        lambda x: hashlib.sha256(
            f"{x['restaurant_name']}_{x['address_fingerprint']}".encode()
        ).hexdigest()[:12],  
        axis=1
    )
    
    return df.drop(columns=['address_fingerprint'])


df = add_restaurant_id(df)

def _normalize_price(price_str):
    price_str = str(price_str).strip().lower()
    return {
        '$': 'low',
        '$$': 'mid',
        '$$$': 'high',
        'low': 'low',
        'mid': 'mid',
        'high': 'high'
    }.get(price_str, 'unknown')

    
def _clean_categories(category_str):
    """Normalize and split category strings"""
    if pd.isna(category_str):
        return []
    return [
        cat.strip().title()
        for cat in str(category_str).split(',')
        if cat.strip() != ''
    ]


def _normalize_price(price_str):
    """Standardize price indicators"""
    price_str = str(price_str).strip().lower()
    return {
        '$': 'low',
        '$$': 'mid',
        '$$$': 'high',
        'low': 'low',
        'mid': 'mid',
        'high': 'high'
    }.get(price_str, 'unknown')

def prepare_chunks(df):
    """Create item-wise chunks for RAG with enriched metadata"""
    chunks = []
        
    for _, row in df.iterrows():
        ingredients = [ing.strip() for ing in row['ingredient_name'].split(',') if ing.strip()]
        
        description = row['menu_description'].strip()
        
        if description == "Unknown":
            description = f"A {row['menu_category']} featuring {', '.join(ingredients)}"
        
        # Build chunk text
        chunk_text = (
            f"{row['menu_item']} ({row['menu_category']}) at {row['restaurant_name']}. "
            f"Description: {description}. Ingredients: {', '.join(ingredients)}. "
            f"Price: {_normalize_price(row['price'])}. Location: {row['city']}, {row['state']}, {row['zip_code']}."
        )
        
        metadata = {
            "restaurant_id": row['restaurant_id'],
            "restaurant_name": row['restaurant_name'].strip(),
            "menu_category": row['menu_category'].strip().title(),
            "menu_description": row['menu_description'].strip(),
            "menu_item": row.get('menu_item', 'Unknown Item').strip(), 
            "price_tier": _normalize_price(row['price']),
            "cuisine_types": [ct.strip() for ct in row['categories'].split(',') if ct.strip()],
            "ingredients": ingredients,
            "location": f"{row['city']}, {row['state']}",
            "item_id": row['item_id']
        }
        
        chunks.append({"text": chunk_text, "metadata": metadata})
    
    return chunks

def get_titan_embeddings(texts, dimensions=512):
    embeddings = []
    cnt = 0 
    for row, text in enumerate(texts):

        body = json.dumps({
            "inputText": text,
            "dimensions": dimensions,
            "normalize": True
        })
        
        response = bedrock_client.invoke_model(
            modelId="amazon.titan-embed-text-v2:0",
            contentType="application/json",
            accept="*/*",
            body=body
        )
        
        # Parse the response
        response_body = json.loads(response['body'].read())
        
        # Extract the embedding
        embedding = response_body['embedding']
        embeddings.append(embedding)
        cnt+=1

        if (cnt %1000) == 0:
            print(cnt)
    
    return np.array(embeddings)

# %%
def create_tfidf_pipeline(chunks):
    """Create TF-IDF vectorizer and matrix using chunk texts"""
    corpus = [chunk['text'] for chunk in chunks]
    vectorizer = TfidfVectorizer(
        stop_words='english',
        ngram_range=(1, 3),
        min_df=2,
        max_df=0.9,
        sublinear_tf=True
    )
    return vectorizer, vectorizer.fit_transform(corpus)

def create_faiss_index(embeddings):
    """Create FAISS index with dimension validation"""
    embeddings = np.array(embeddings).astype('float32')
    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(embeddings)
    return index


def retrieve_with_tfidf(query, chunks, vectorizer, tfidf_matrix, top_n=50):
    query_vec = vectorizer.transform([query])
    
    cosine_sim = cosine_similarity(query_vec, tfidf_matrix).flatten()
    
    # Pair scores with chunks using matrix row indices
    scored_chunks = sorted(
        [(i, score) for i, score in enumerate(cosine_sim)],
        key=lambda x: x[1], 
        reverse=True
    )[:top_n]
    
    return [{
        "metadata": {
            **chunks[i]["metadata"],
            "text": chunks[i]["text"],
            "chunk_id": chunks[i]["chunk_id"]
        },
        "text": chunks[i]["text"],
        "chunk_id": chunks[i]["chunk_id"],
        "score": float(score)
    } for i, score in scored_chunks]
    
def refine_with_bm25(query, tfidf_results, top_n=20):
    texts = [res["text"] for res in tfidf_results]
    bm25 = BM25Okapi([doc.split() for doc in texts])
    scores = bm25.get_scores(query.split())
    
    return [{
        "metadata": {  # Move all fields into metadata
            **res["metadata"],
            "text": res["text"],
            "chunk_id": res["chunk_id"]
        },
        "text": res["text"],
        "chunk_id": res["chunk_id"],
        "score": float(scores[i])
    } for i, res in enumerate(tfidf_results)][:top_n]

def retrieve_with_embeddings(query, faiss_index, faiss_index_to_chunk, top_n=20):
    query_embedding = get_titan_embeddings([query])
    distances, indices = faiss_index.search(
        np.array(query_embedding).astype('float32'), 
        top_n
    )
    
    return [{
        "metadata": {  # Move all fields into metadata
            **faiss_index_to_chunk[idx],
            "text": faiss_index_to_chunk[idx]["text"],
            "chunk_id": faiss_index_to_chunk[idx]["chunk_id"]
        },
        "text": faiss_index_to_chunk[idx]["text"],
        "chunk_id": faiss_index_to_chunk[idx]["chunk_id"],
        "score": float(1 / (1 + distances[0][i]))
    } for i, idx in enumerate(indices[0]) if idx in faiss_index_to_chunk]
    
def hybrid_retrieval(query, chunks, vectorizer, tfidf_matrix, 
                    faiss_index, faiss_index_to_chunk, reranker, top_k=5):
    """Hybrid retrieval with consistent metadata structure"""
    # Retrieve and refine results
    tfidf_results = retrieve_with_tfidf(query, chunks, vectorizer, tfidf_matrix, 50)
    bm25_results = refine_with_bm25(query, tfidf_results, 20)
    vector_results = retrieve_with_embeddings(query, faiss_index, faiss_index_to_chunk, 20)
    
    # Combine and deduplicate
    seen = set()
    combined = []
    for res in bm25_results + vector_results:
        uid = res["metadata"].get("item_id", f"{res['metadata']['restaurant_id']}_{res['metadata']['menu_item']}")
        if uid not in seen:
            seen.add(uid)
            combined.append(res)
    
    # Rerank final results
    return rerank_results(query, combined, reranker, top_k)
    
    


def rerank_results(query, combined_results, reranker, top_k=5):
    """Re-rank retrieved results using a Cross-Encoder"""
    if not combined_results:
        return []

    query_doc_pairs = [(query, res["text"]) for res in combined_results]

    scores = reranker.predict(query_doc_pairs)

    for i, res in enumerate(combined_results):
        res['combined_score'] = scores[i]
        res['reranker_score'] = scores[i]  
    
    sorted_results = sorted(combined_results, key=lambda x: x["reranker_score"], reverse=True)[:top_k]
    
    return sorted_results

def initialize_system(chunks, embeddings):
    chunk_embeddings = np.array(embeddings).astype('float32')
    faiss_index = create_faiss_index(chunk_embeddings)
    
    # Create index mapping
    faiss_index_to_chunk = {
        i: {
            **chunk["metadata"],
            "text": chunk["text"],
            "chunk_id": chunk["chunk_id"]
        } for i, chunk in enumerate(chunks)
    }
    
    vectorizer, tfidf_matrix = create_tfidf_pipeline(chunks)
    
    return {
        "faiss_index": faiss_index,
        "faiss_index_to_chunk": faiss_index_to_chunk,
        "vectorizer": vectorizer,
        "tfidf_matrix": tfidf_matrix,
        "reranker": CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
    }

def generate_final_response(query, retrieved_chunks, historic_context, bedrock_client):
    restaurant_entries = []
    for chunk in retrieved_chunks[:3]: 
        meta = chunk.get('metadata', {})
        entry = (
            f"Restaurant: {meta.get('restaurant_name', 'Unknown')}\n"
            f"- Menu Item: {meta.get('menu_item', 'N/A')} (ID: {meta.get('item_id', '')})\n"
            f"- Price: {meta.get('price_tier', '').capitalize()}\n"
            f"- Cuisine: {', '.join(meta.get('cuisine_types', []))}\n"
            f"- Ingredients: {', '.join(meta.get('ingredients', []))}"
        )
        restaurant_entries.append(entry)

    # Preparing historical context if available
    history_block = ""
    if historic_context.get('Historic_context', -1) not in [-1, "Data not available on Wikipedia"]:
        history_block = (
            f"\n\nHistorical Context: {historic_context['Historic_context']}"
            f"\nSource: {historic_context['link']}"
        )

    generation_prompt = f"""You are a restaurant information specialist. Use this structure:

    {{restaurants}}

    {{history}}

    **Guidelines**
    - Present restaurants in bullet points
    - ALWAYS include item IDs from metadata
    - For history: Only include if relevant to query
    - If asked sources: Reference item IDs like "(ID: 24399115)"
    - Never mention chunks or retrieval process

    **Current Query**: {query}
    """

    payload = {
        "modelId": "arn:aws:bedrock:us-east-2:302263051966:inference-profile/us.anthropic.claude-3-5-haiku-20241022-v1:0",
        "body": json.dumps({
            "anthropic_version": "bedrock-2023-05-31",
            "max_tokens": 500,
            "temperature": 0.2,
            "system": """You are a restaurant concierge for San Francisco. Follow these rules:
            1. Use ONLY the provided restaurant metadata
            2. For history: Use only the provided Wikipedia context
            3. Always cite item IDs from metadata
            4. If no history requested: Don't mention it""",
            "messages": [{
                "role": "user",
                "content": [{
                    "type": "text",
                    "text": generation_prompt.format(
                        restaurants="\n\n".join(restaurant_entries),
                        history=history_block
                    )
                }]
            }]
        })
    }

    try:
        response = bedrock_client.invoke_model(**payload)
        result = json.loads(response["body"].read().decode("utf-8"))
        raw_response = result.get("content", [{}])[0].get("text", "")
        
        return raw_response.replace("(ID:", "(Item ID:").replace("ID:", "Item ID:")
    
    except Exception as e:
        print(f"Generation error: {str(e)[:200]}")
        return f"Could not generate response. Please check your query. Reference IDs: {', '.join([str(c['metadata']['item_id']) for c in retrieved_chunks[:3]])}"
        
def find_information_missing_in_chunks(query, retrieved_chunks, bedrock_client):
    
    enhancement_prompt = f"""Analyze the given restaurant-related query and retrieved search results.  
    Determine if the query explicitly asks for historical or cultural context about a dish, ingredient, or restaurant practice,  
    and check whether this information is present in the retrieved search results.  

    **INPUT:**  
    - **Query:** {query}  
    - **Retrieved Chunks:** {retrieved_chunks}  

    **OUTPUT GUIDELINES:**  
    - If the query **does not explicitly** ask for historical/cultural context (e.g., it only asks for restaurants or locations), return an **empty string** (`""`).  
    - If the query **explicitly** asks for historical or cultural context, check if the retrieved chunks answer it.  
    - If the historical or cultural context is required but **not answered** in the retrieved chunks, return a **concise Wikipedia search term** in the format: `"History of <topic>"`.  
    - Do **not** generate historical terms unless they are explicitly requested.  
    - Do **not** include any extra text, explanations, or formatting beyond the required search term.  
"""

    payload = {
        "modelId": "arn:aws:bedrock:us-east-2:302263051966:inference-profile/us.anthropic.claude-3-5-haiku-20241022-v1:0",
        "body": json.dumps({
            "anthropic_version": "bedrock-2023-05-31",
            "max_tokens": 200,
            "temperature": 0.3,
            "system": """You are an expert in restaurant data analysis.  
Your task is to determine if a restaurant-related query requires missing historical or cultural context.  
- Only return a Wikipedia search term **if the query explicitly asks for historical or cultural context** and the retrieved information does not answer it.  
- If the query is about finding restaurants, return an empty string.  
- Do not assume historical context is needed just because a food item is mentioned.""",
            "messages": [{
                "role": "user",
                "content": [{
                    "type": "text", 
                    "text": enhancement_prompt
                }]
            }]
        })
    }

    try:
        response = bedrock_client.invoke_model(**payload)
        result = json.loads(response["body"].read().decode("utf-8"))
        search_term = result.get("content", [{}])[0].get("text", "").strip()
        
        if search_term:
            wiki_summary =  fetch_wikipedia_summary(search_term[1: -1])
            if wiki_summary:
                url = f"https://en.wikipedia.org/api/rest_v1/page/summary/"
                link = url + search_term[1:-1]
                return {"Historic_context" : wiki_summary, "link" : link}
            else:
                return {"Historic_context" : "Data not available on Wikipedia", "link" : "Data not available on Wikipedia"}

        return {"Historic_context" : -1, "link" : "Data not available on Wikipedia"}
        
    except Exception as e:
        print(f"Analysis error: {str(e)[:200]}")
        return {"Historic_context" : -1, "link" : "Data not available on Wikipedia"}
        
def fetch_wikipedia_summary(title):
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{title}"
    response = requests.get(url)
    return response.json().get("extract", "-1")

# %%
from sentence_transformers import CrossEncoder

reranker = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')


query = QnA["question"][0]

system = initialize_system(chunks, loaded_embeddings)


results = hybrid_retrieval(
    query_text,
    chunks=chunks[:1100],
    vectorizer=system["vectorizer"],
    tfidf_matrix=system["tfidf_matrix"],
    faiss_index=system["faiss_index"],
    faiss_index_to_chunk=system["faiss_index_to_chunk"],
    reranker=system["reranker"],
    top_k=5
)

for res in results:
    print(f"""\
[Chunk {res['chunk_id']}] {res['metadata']['menu_item']}
Combined Score: {res['combined_score']:.2f} (Reranker: {res['reranker_score']:.2f}, Original: {res['score']:.2f})
{res['metadata']['menu_description']}
Ingredients: {', '.join(res['metadata']['ingredients'])}
{'-'*40}""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       3 reranker = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')
#       6 query = QnA["question"][0]
# ----> 8 system = initialize_system(chunks, loaded_embeddings)
#      11 results = hybrid_retrieval(
#      12     query_text,
#      13     chunks=chunks[:1100],
#    (...)
#      19     top_k=5
#      20 )
#      22 for res in results:
#
# NameError: name 'loaded_embeddings' is not defined

# %%
# Initialize variables to track hit scores
hit_scores = []

# Iterate over QnA dataset to evaluate retrieval performance
for i, row in QnA.iterrows():
    query_text = row["question"]  
    correct_chunk_id = row["chunk_id"]  

    
    # Retrieve top-k results using the hybrid retrieval system
    retrieved_results = hybrid_retrieval(
        query_text,
        chunks=chunks[:1100],  # Ensure consistent chunk structure
        vectorizer=system["vectorizer"],
        tfidf_matrix=system["tfidf_matrix"],
        faiss_index=system["faiss_index"],
        faiss_index_to_chunk=system["faiss_index_to_chunk"],
        reranker=system["reranker"],
        top_k=5
    )

    # Check if the correct chunk is among retrieved results
    hit = int(any(result["chunk_id"] == correct_chunk_id for result in retrieved_results))
    hit_scores.append(hit)

    # Debugging info
    print(f"Question: {query_text}")
    print(f"Correct Chunk ID: {correct_chunk_id}")
    print(f"Retrieved Chunk IDs: {[result['chunk_id'] for result in retrieved_results]}")
    print(f"Hit: {hit}\n")

# Compute final hit rate
overall_hit_rate = sum(hit_scores) / len(hit_scores)
print(f"Overall Hit Rate: {overall_hit_rate * 100:.2f}%")
# Out:
# Question: In the heart of San Francisco's vibrant culinary scene, which liquid velvet whispers tales of Portuguese tradition while dancing with dark chocolate and caramel notes?
# Correct Chunk ID: 0
# Retrieved Chunk IDs: [0, 580, 896, 252, 132]
# Hit: 1
#
# Question: What artisanal San Francisco treat transforms a humble nut into a crave-worthy delicacy with just a whisper of oceanic seasoning?
# Correct Chunk ID: 1
# Retrieved Chunk IDs: [131, 1, 794, 4, 0]
# Hit: 1
#
# Question: What Mediterranean snack transforms a simple olive into a zesty flavor adventure with just two unexpected botanical companions?
# Correct Chunk ID: 2
# Retrieved Chunk IDs: [2, 232, 876, 9, 865]
# Hit: 1
#
# Question: Where can you find a sweet, spreadable creation that marries fruit and dairy in the Mission District's culinary landscape?
# Correct Chunk ID: 3
# Retrieved Chunk IDs: [12, 217, 131, 205, 247]
# Hit: 0
#
# Question: What culinary creation transforms a simple spread into a symphony of textures that could make a cheese board blush?
# Correct Chunk ID: 4
# Retrieved Chunk IDs: [4, 5, 871, 62, 19]
# Hit: 1
#
# Question: What delicate appetizer transforms humble offal into a luxurious spread that pairs perfectly with sweet-tart preserved fruit on crisp toast?
# Correct Chunk ID: 5
# Retrieved Chunk IDs: [18, 19, 4, 247, 549]
# Hit: 0
#
# Question: Where in the Mission District might a seafood lover find a delicate dish that transforms raw fish into a vibrant canvas of Korean and Latin American flavor profiles?
# Correct Chunk ID: 6
# Retrieved Chunk IDs: [694, 733, 681, 698, 12]
# Hit: 0
#
# Question: In a farm-to-table haven where seasonal produce whispers its story, what crisp, verdant side dish captures the essence of early summer's first harvest?
# Correct Chunk ID: 7
# Retrieved Chunk IDs: [205, 247, 1078, 944, 755]
# Hit: 0
#
# Question: What small plate showcases a Mediterranean-inspired garden on a plate, where crisp green meets zesty herbs and a nutty dressing?
# Correct Chunk ID: 8
# Retrieved Chunk IDs: [8, 10, 11, 7, 975]
# Hit: 1
#
# Question: In a culinary landscape where heritage meets innovation, what delicate dish transforms humble legumes into a canvas of vibrant Sicilian elegance?
# Correct Chunk ID: 9
# Retrieved Chunk IDs: [9, 226, 893, 358, 13]
# Hit: 1
#
# Question: Which Bay Area dish transforms summer's sweetest harvest into a creamy canvas of nutty elegance?
# Correct Chunk ID: 10
# Retrieved Chunk IDs: [131, 893, 0, 118, 744]
# Hit: 0
#
# Question: What cool, verdant dish perfectly balances summer's heat with a zesty botanical crunch?
# Correct Chunk ID: 11
# Retrieved Chunk IDs: [205, 129, 118, 117, 893]
# Hit: 0
#
# Question: Which San Francisco dish artfully blends Mission District produce with a nutty, spicy condiment that transforms humble ingredients into a culinary revelation?
# Correct Chunk ID: 12
# Retrieved Chunk IDs: [12, 131, 217, 0, 681]
# Hit: 1
#
# Question: In a San Francisco pizzeria where flavors dance like a culinary symphony, which white-sauced maestro sits proudly at the twentieth position on the menu?
# Correct Chunk ID: 13
# Retrieved Chunk IDs: [18, 860, 19, 14, 929]
# Hit: 0
#
# Question: What savory slice would make a pizza purist in the Mission District pause and reconsider traditional topping combinations?
# Correct Chunk ID: 14
# Retrieved Chunk IDs: [12, 334, 341, 339, 340]
# Hit: 0
#
# Question: Which Bay Area dessert transforms humble farmers' market berries into a rustic, cream-crowned delicacy that whispers of California's culinary artistry?
# Correct Chunk ID: 16
# Retrieved Chunk IDs: [16, 17, 86, 0, 540]
# Hit: 1
#
# Question: In a city known for culinary innovation, which creamy, milk-soaked dessert becomes a canvas for golden fruit at spot number 20?
# Correct Chunk ID: 17
# Retrieved Chunk IDs: [17, 16, 0, 19, 790]
# Hit: 1
#
# Question: Which effervescent French treasure from a prestigious terroir captures the essence of Champagne's artistry in a single, elegant sip?
# Correct Chunk ID: 18
# Retrieved Chunk IDs: [40, 135, 39, 133, 134]
# Hit: 0
#
# Question: Which Austrian white wine, known for its distinctive green apple and white pepper notes, offers a crisp minerality that captures the essence of its Alpine terroir in a San Francisco wine spot?
# Correct Chunk ID: 20
# Retrieved Chunk IDs: [20, 42, 18, 41, 19]
# Hit: 1
#
# Question: Which San Francisco wine embodies the crisp essence of Hungarian terroir while dancing with green apple notes at a mid-tier price point?
# Correct Chunk ID: 21
# Retrieved Chunk IDs: [42, 18, 1091, 19, 40]
# Hit: 0
#
# Question: Which Austrian red wine blend captures the essence of dark fruit and subtle spice in a velvety symphony of flavor at the 20th spot on a sommelier's must-try list?
# Correct Chunk ID: 23
# Retrieved Chunk IDs: [23, 24, 136, 0, 21]
# Hit: 1
#
# Question: Which bold, velvety wine from San Francisco embodies the rich heritage of South African grape cultivation while offering a sensory journey through dark fruit and subtle spice?
# Correct Chunk ID: 24
# Retrieved Chunk IDs: [24, 136, 39, 0, 92]
# Hit: 1
#
# Question: What effervescent libation captures the essence of San Francisco's botanical spirit at the intersection of herbal complexity and refreshing lightness?
# Correct Chunk ID: 25
# Retrieved Chunk IDs: [25, 19, 326, 18, 824]
# Hit: 1
#
# Question: What sophisticated libation captures San Francisco's artisanal spirit, blending dark fruit nuances with botanical complexity and a citrus whisper?
# Correct Chunk ID: 26
# Retrieved Chunk IDs: [326, 24, 46, 18, 91]
# Hit: 0
#
# Question: What Hungarian nectar, known for its royal legacy and golden sweetness, transforms a San Francisco wine list into a liquid treasure map?
# Correct Chunk ID: 27
# Retrieved Chunk IDs: [136, 47, 44, 958, 0]
# Hit: 0
#
# Question: Which San Francisco craft brewery's hoppy creation sits at the intersection of flavor and urban brewing innovation, nestled in the vibrant 94110 zip code?
# Correct Chunk ID: 28
# Retrieved Chunk IDs: [34, 960, 917, 19, 958]
# Hit: 0
#
# Question: Which craft beer embodies the essence of California's brewing artistry, blending tropical fruit notes with earthy undertones in a velvety hazy IPA experience?
# Correct Chunk ID: 29
# Retrieved Chunk IDs: [29, 38, 34, 28, 987]
# Hit: 1
#
# Question: In a San Francisco cocktail bar where musical nostalgia meets coastal Italian inspiration, what libation captures the melodic essence of ancient stringed instruments while offering a zesty Mediterranean twist?
# Correct Chunk ID: 30
# Retrieved Chunk IDs: [43, 699, 19, 18, 0]
# Hit: 0
#
# Question: What cocktail embodies both botanical sophistication and colonial history, often served in a neighborhood known for its vibrant mixology scene?
# Correct Chunk ID: 31
# Retrieved Chunk IDs: [699, 19, 18, 276, 44]
# Hit: 0
#
# Question: What herbal elixir from San Francisco might make a cocktail enthusiast's tonic dreams come true at a modest mid-range price point?
# Correct Chunk ID: 32
# Retrieved Chunk IDs: [32, 31, 900, 30, 825]
# Hit: 1
#
# Question: Which carbonated beverage, known for its spicy root flavor, sits at the 20th position on a local San Francisco menu with a mid-range price point?
# Correct Chunk ID: 33
# Retrieved Chunk IDs: [34, 960, 0, 36, 954]
# Hit: 0
#
# Question: Which carbonated classic from a nostalgic American beverage line might you find nestled in a San Francisco neighborhood, promising a taste of traditional soda craftsmanship?
# Correct Chunk ID: 34
# Retrieved Chunk IDs: [175, 25, 593, 541, 325]
# Hit: 0
#
# Question: What citrus variety transforms a classic beverage into a crimson-hued Mediterranean refreshment, bearing the name of an iconic Italian sparkling water brand?
# Correct Chunk ID: 35
# Retrieved Chunk IDs: [43, 42, 19, 596, 18]
# Hit: 0
#
# Question: Which citrusy beverage embodies both its sparkling Italian heritage and a zesty fruit essence, nestled in the heart of San Francisco's vibrant 94110 neighborhood?
# Correct Chunk ID: 36
# Retrieved Chunk IDs: [43, 42, 326, 19, 22]
# Hit: 0
#
# Question: What effervescent beverage might make an Italian nobleman feel right at home in the Mission District?
# Correct Chunk ID: 37
# Retrieved Chunk IDs: [25, 217, 43, 12, 959]
# Hit: 0
#
# Question: Which effervescent libation embodies the pinnacle of French viticulture, balancing delicate floral notes with a toasted brioche essence, while representing an elegant expression of terroir from a renowned San Francisco establishment?
# Correct Chunk ID: 39
# Retrieved Chunk IDs: [40, 18, 25, 44, 46]
# Hit: 0
#
# Question: Which effervescent elixir captures the delicate dance of strawberry and rose petals, nestled in a San Francisco sanctuary of refined taste?
# Correct Chunk ID: 40
# Retrieved Chunk IDs: [22, 44, 19, 18, 32]
# Hit: 0
#
# Question: Which effervescent South African wine, crafted by a legendary Cape Town smoking companion, offers a crisp toast to bubbling elegance at a modest twenty-spot?
# Correct Chunk ID: 41
# Retrieved Chunk IDs: [40, 46, 44, 39, 41]
# Hit: 1
#
# Question: Which sparkling wine embodies the vibrant dance of green apple and verdiso, capturing the essence of San Francisco's effervescent spirit in a single, crisp sip?
# Correct Chunk ID: 42
# Retrieved Chunk IDs: [42, 44, 46, 43, 18]
# Hit: 1
#
# Question: Where can you find a sunkissed Italian sparkler that pirouettes with petite bubbles and whispers of floral sweetness in the heart of San Francisco's vibrant Mission District?
# Correct Chunk ID: 43
# Retrieved Chunk IDs: [43, 19, 18, 37, 596]
# Hit: 1
#
# Question: Which effervescent San Francisco wine captures the essence of a fresh, zesty green apple dance with a whisper of floral charm?
# Correct Chunk ID: 44
# Retrieved Chunk IDs: [44, 42, 46, 43, 18]
# Hit: 1
#
# Question: What sparkling libation captures the wild spirit of San Francisco's natural wine scene, dancing with cherry and wild strawberry notes while embracing an earthy effervescence?
# Correct Chunk ID: 46
# Retrieved Chunk IDs: [46, 43, 19, 18, 45]
# Hit: 1
#
# Question: Which San Francisco dish artfully combines the creamy decadence of an Italian cheese with a vibrant mosaic of unexpected local ingredients that dance between earthy and bright?
# Correct Chunk ID: 48
# Retrieved Chunk IDs: [967, 0, 908, 871, 340]
# Hit: 0
#
# Question: In San Francisco's culinary landscape, which dish blends Japanese-inspired delicacy with a playful coastal twist, transforming raw seafood into an artful composition of unexpected flavors?
# Correct Chunk ID: 49
# Retrieved Chunk IDs: [723, 732, 715, 710, 724]
# Hit: 0
#
# Question: Which San Francisco pasta dish transforms classic Italian meat traditions into a luxurious happy hour symphony of wagyu, veal, and pork dancing in a San Marzano embrace?
# Correct Chunk ID: 50
# Retrieved Chunk IDs: [50, 356, 355, 859, 361]
# Hit: 1
#
# Question: What delicate dish captures the essence of a San Francisco happy hour, where forest-floor umami meets creamy dairy in a single, elegant bite?
# Correct Chunk ID: 51
# Retrieved Chunk IDs: [18, 0, 17, 19, 10]
# Hit: 0
#
# Question: Which San Francisco dish combines the underground luxury of forest-dwelling fungi with a classic Italian pasta technique, transforming humble ingredients into a culinary masterpiece at a neighborhood gem known for innovative small plates?
# Correct Chunk ID: 52
# Retrieved Chunk IDs: [360, 891, 859, 1024, 352]
# Hit: 0
#
# Question: Which trio of liquid companions might make a sommelier smile during the golden hours at a culinary cousin's establishment?
# Correct Chunk ID: 53
# Retrieved Chunk IDs: [53, 132, 48, 50, 51]
# Hit: 1
#
# Question: In the culinary landscape of San Francisco's Mission District, which bite-sized delicacy combines the heat of chili with the tang of fermented grain liquid, nestled within a soft wrapper at a restaurant with familial nomenclature?
# Correct Chunk ID: 54
# Retrieved Chunk IDs: [12, 217, 54, 2, 506]
# Hit: 1
#
# Question: Which crispy, herbaceous small plate perfectly captures San Francisco's culinary playfulness with a Mediterranean-inspired twist?
# Correct Chunk ID: 55
# Retrieved Chunk IDs: [549, 8, 10, 11, 9]
# Hit: 0
#
# Question: In a San Francisco kitchen where verdant ingredients dance with cured delicacies, what monochromatic soup whispers tales of seasonal elegance?
# Correct Chunk ID: 56
# Retrieved Chunk IDs: [18, 615, 419, 777, 56]
# Hit: 1
#
# Question: Which San Francisco small plate perfectly captures the delicate balance between oceanic umami and garden-fresh crunch?
# Correct Chunk ID: 57
# Retrieved Chunk IDs: [10, 11, 8, 9, 7]
# Hit: 0
#
# Question: In a culinary landscape where seafood meets innovation, what San Francisco dish artfully combines the delicate dance of rock shrimp with the woodland whispers of fiddlehead, all nestled on a canvas of wild rice?
# Correct Chunk ID: 58
# Retrieved Chunk IDs: [129, 58, 707, 710, 119]
# Hit: 1
#
# Question: Where might a carnivore find a culinary canvas of local fungi and grass-fed beef nestled in the heart of the Mission District?
# Correct Chunk ID: 59
# Retrieved Chunk IDs: [910, 12, 59, 6, 61]
# Hit: 1
#
# Question: In a culinary landscape where ocean meets garden, what delicate dish transforms Tuesday through Thursday into a five-act seafood symphony at a San Francisco address that hints at familial intimacy?
# Correct Chunk ID: 60
# Retrieved Chunk IDs: [129, 694, 736, 363, 748]
# Hit: 0
#
# Question: In a culinary landscape where local ingredients dance on the palate, which vegetarian dish transforms humble black trumpet mushrooms into a symphony of textures and flavors?
# Correct Chunk ID: 61
# Retrieved Chunk IDs: [61, 118, 120, 18, 1032]
# Hit: 1
#
# Question: Where might a culinary adventurer find a seafood-inspired symphony that dances between Thai and Californian flavors, nestled in a neighborhood known for its innovative dining experiences?
# Correct Chunk ID: 63
# Retrieved Chunk IDs: [685, 710, 746, 682, 699]
# Hit: 0
#
# Question: In a culinary landscape where local ingredients dance with luxurious fungi, which San Francisco tasting menu whispers tales of earthy chanterelles and rare Perigord treasures?
# Correct Chunk ID: 64
# Retrieved Chunk IDs: [64, 112, 129, 1024, 82]
# Hit: 1
#
# Question: Which San Francisco culinary experience transforms local marine delicacies into an artful 5-part symphony of wild textures and oceanic flavors?
# Correct Chunk ID: 65
# Retrieved Chunk IDs: [129, 65, 19, 6, 0]
# Hit: 1
#
# Question: Where might a culinary adventurer find a meticulously crafted 5-course symphony that transforms a prime NY steak into an artistic exploration of earthy boletus, delicate asparagus, and rustic alliums?
# Correct Chunk ID: 66
# Retrieved Chunk IDs: [66, 82, 370, 59, 129]
# Hit: 1
#
# Question: In a culinary landscape where texture meets tradition, what five-part symphony of flavors transforms humble ingredients into an artful exploration of plant-based gastronomy at a San Francisco address that hints at familial intimacy?
# Correct Chunk ID: 67
# Retrieved Chunk IDs: [112, 19, 110, 13, 882]
# Hit: 0
#
# Question: What culinary journey transforms a humble Tuesday through Thursday into a five-act symphony of Brokaw citrus, hojicha, and coconut whispers?
# Correct Chunk ID: 68
# Retrieved Chunk IDs: [68, 131, 122, 89, 18]
# Hit: 1
#
# Question: What delectable dessert journey awaits at a San Francisco establishment where chocolate meets pecans in a five-act culinary performance?
# Correct Chunk ID: 69
# Retrieved Chunk IDs: [69, 0, 992, 377, 896]
# Hit: 1
#
# Question: What culinary creation transforms oceanic delicacies into a decadent dessert that blurs the line between savory and sweet at a San Francisco restaurant known for innovative gastronomy?
# Correct Chunk ID: 71
# Retrieved Chunk IDs: [0, 540, 17, 16, 4]
# Hit: 0
#
# Question: Where in San Francisco might a culinary adventurer discover a delicate fusion of Miyazaki's regional flavors and modern chili-infused technique, nestled within a neighborhood known for innovative dining experiences?
# Correct Chunk ID: 72
# Retrieved Chunk IDs: [72, 54, 2, 19, 435]
# Hit: 1
#
# Question: What culinary creation transforms a classic Italian rice dish into a coastal California symphony of umami and brightness?
# Correct Chunk ID: 73
# Retrieved Chunk IDs: [185, 893, 707, 976, 894]
# Hit: 0
#
# Question: Where can you find a rustic Italian bread that whispers of Tuscan hillsides, transforms weekly into a culinary canvas, and nestles in a neighborhood that sounds like a familial gathering?
# Correct Chunk ID: 74
# Retrieved Chunk IDs: [348, 3, 875, 872, 83]
# Hit: 0
#
# Question: What delicate Mediterranean creature might you find nestled among a symphony of rustic legumes and verdant herbs in a Mission District culinary canvas?
# Correct Chunk ID: 75
# Retrieved Chunk IDs: [12, 9, 2, 891, 1024]
# Hit: 0
#
# Question: In a San Francisco kitchen where marine delicacies dance with Japanese-inspired nuance, what avant-garde dish might showcase both raw hamachi and delicate crab in a single, artful composition?
# Correct Chunk ID: 76
# Retrieved Chunk IDs: [127, 718, 720, 76, 733]
# Hit: 1
#
# Question: In a culinary symphony where sea meets sweet, what avant-garde dessert transforms oceanic delicacies into a decadent finale at a San Francisco hotspot?
# Correct Chunk ID: 77
# Retrieved Chunk IDs: [0, 979, 992, 540, 17]
# Hit: 0
#
# Question: In a San Francisco kitchen where culinary poetry meets precision, what dish transforms oceanic sweetness into a creamy canvas of regional elegance?
# Correct Chunk ID: 79
# Retrieved Chunk IDs: [3, 435, 4, 13, 5]
# Hit: 0
#
# Question: In a San Francisco kitchen where culinary poetry meets precision, what dish transforms local seafood into an artful composition of green whispers and wild textures?
# Correct Chunk ID: 80
# Retrieved Chunk IDs: [695, 732, 694, 693, 363]
# Hit: 0
#
# Question: In a culinary landscape where local ingredients dance with global inspirations, which San Francisco dish transforms a classic protein into a ginger-kumquat symphony at 94110's hidden gem?
# Correct Chunk ID: 81
# Retrieved Chunk IDs: [109, 81, 6, 18, 13]
# Hit: 1
#
# Question: On a culinary journey through San Francisco's Mission District, which dish showcases a local chef's artful interpretation of a classic cut with an earthy woodland whisper?
# Correct Chunk ID: 82
# Retrieved Chunk IDs: [217, 12, 435, 185, 13]
# Hit: 0
#
# Question: In a San Francisco kitchen where culinary artistry meets local ingredients, what rustic Italian bread becomes a canvas for luxurious spreads like ramp butter and taleggio fonduta?
# Correct Chunk ID: 83
# Retrieved Chunk IDs: [83, 3, 118, 348, 64]
# Hit: 1
#
# Question: What culinary creation transforms a humble vegetable into a symphony of smoky, tangy, and herbaceous flavors that could make even a brussels sprout skeptic surrender?
# Correct Chunk ID: 84
# Retrieved Chunk IDs: [113, 121, 918, 84, 67]
# Hit: 1
#
# Question: What delicate marine arthropod meets Southern-inspired culinary creativity in a San Francisco kitchen, transforming from sea creature to crispy delicacy?
# Correct Chunk ID: 85
# Retrieved Chunk IDs: [697, 152, 637, 185, 1]
# Hit: 0
#
# Question: What delicate dessert combines the richness of chocolate with a symphony of unexpected flavor companions like black sesame, candied almonds, and a whisper of amaretto?
# Correct Chunk ID: 86
# Retrieved Chunk IDs: [86, 123, 992, 0, 979]
# Hit: 1
#
# Question: Which San Francisco dessert artfully combines citrus, creamy cheese, and nutty frozen delight in a 94110 zip code culinary canvas?
# Correct Chunk ID: 87
# Retrieved Chunk IDs: [540, 376, 0, 375, 17]
# Hit: 0
#
# Question: What delicate Japanese-inspired dessert combines roasted green tea, creamy coconut, and a textural granola element in a San Francisco culinary hotspot?
# Correct Chunk ID: 89
# Retrieved Chunk IDs: [131, 106, 89, 540, 122]
# Hit: 1
#
# Question: Which Hungarian wine captures the essence of liquid gold, balancing sweetness and complexity with a legendary classification system that transforms noble rot into nectar?
# Correct Chunk ID: 90
# Retrieved Chunk IDs: [47, 44, 100, 101, 136]
# Hit: 0

# %%
overall_hit_rate
# Out:
# 0.48846153846153845

# %% [markdown]
# ## Lets see how the chunks with better descriptions behave

# %%
with open('chunks_new.pkl', 'rb') as f:
    chunks_enhanced = pickle.load(f)

# %%
texts_enhanced = [chunk["text"] for chunk in chunks_enhanced]
embeddings_enhanced = get_titan_embeddings(texts_enhanced[:1100])
# Out:
# 1000

# %%
with open('embeddings_enhanced.pkl', 'wb') as f:
    pickle.dump(embeddings_enhanced, f)

with open('embeddings_enhanced.pkl', 'rb') as f:
    loaded_embeddings_enhanced = pickle.load(f)

# %%
system = initialize_system(chunks_enhanced[:1100], loaded_embeddings_enhanced)

query = "Resturants serving sushi?"

results = hybrid_retrieval(
    query,
    chunks=chunks_enhanced[:1100],
    vectorizer=system["vectorizer"],
    tfidf_matrix=system["tfidf_matrix"],
    faiss_index=system["faiss_index"],
    faiss_index_to_chunk=system["faiss_index_to_chunk"],
    reranker=system["reranker"],
    top_k=5
)

for res in results:
    print(f"""\
[Chunk {res['chunk_id']}] {res['metadata']['menu_item']}
Combined Score: {res['combined_score']:.2f} (Reranker: {res['reranker_score']:.2f}, Original: {res['score']:.2f})
{res['metadata']['menu_description']}
Ingredients: {', '.join(res['metadata']['ingredients'])}
{'-'*40}""")
# Out:
# [Chunk 689] 3 sushi special combo
# Combined Score: -3.93 (Reranker: -3.93, Original: 0.00)
# eight pieces of caterpillar roll two pieces of salmon nigiri two pieces of tuna nigiri
# Ingredients: caterpillar roll, salmon, tuna
# ----------------------------------------
# [Chunk 727] 303 hamachi nigiri sushi
# Combined Score: -3.95 (Reranker: -3.95, Original: 0.00)
# yellow tail two pieces
# Ingredients: yellow tail, rice
# ----------------------------------------
# [Chunk 726] 301 maguro nigiri sushi
# Combined Score: -4.31 (Reranker: -4.31, Original: 0.00)
# tuna two pieces
# Ingredients: rice, tuna
# ----------------------------------------
# [Chunk 725] 302 sake nigiri sushi
# Combined Score: -4.52 (Reranker: -4.52, Original: 0.00)
# salmon two pieces
# Ingredients: salmon, rice
# ----------------------------------------
# [Chunk 730] 305 ebi nigiri sushi
# Combined Score: -4.83 (Reranker: -4.83, Original: 0.00)
# cooked shrimp two pieces
# Ingredients: cooked shrimp, rice
# ----------------------------------------

# %%
# Initialize variables to track hit scores
hit_scores = []

# Iterate over QnA dataset to evaluate retrieval performance
for i, row in QnA.iterrows():
    query_text = row["question"]  
    correct_chunk_id = row["chunk_id"]  

    
    # Retrieve top-k results using the hybrid retrieval system
    retrieved_results = hybrid_retrieval(
    query_text,
    chunks=chunks_enhanced[:1100],
    vectorizer=system["vectorizer"],
    tfidf_matrix=system["tfidf_matrix"],
    faiss_index=system["faiss_index"],
    faiss_index_to_chunk=system["faiss_index_to_chunk"],
    reranker=system["reranker"],
    top_k=5
)
    # Check if the correct chunk is among retrieved results
    hit = int(any(result["chunk_id"] == correct_chunk_id for result in retrieved_results))
    hit_scores.append(hit)


# Compute final hit rate
overall_hit_rate = sum(hit_scores) / len(hit_scores)
print(f"Overall Hit Rate: {overall_hit_rate * 100:.2f}%")
# Out:
# Overall Hit Rate: 65.77%

# %% [markdown]
# > Enhanced description really helped with better retrieval.  The hit rate increased by near about 22%.
# >
# > Lets work on the generation end now.

# %% [markdown]
# > This function would help extract data from wikipedia summary page on it

# %% [markdown]
# > Lets work on 75% data atleast.
#
# > I would enhance 7500 chunks out of some 10k chunks.

# %%
def enhance_description_with_llm(item_data, bedrock_client):
    """
    Enriches menu item descriptions using LLM to better match potential user queries.
    """
    enhancement_prompt = f"""Analyze this menu item and enhance its description to include:
1. Sensory details (texture, aroma, taste)
2. Pairing suggestions
3. Dietary information
4. Usage scenarios
5. Complementary ingredients
6. Also include cuisines, cultural/historical context around the dishes.

**Output GUIDELINES**
- Keep it concise. Less than 5 sentences.
- Maintain factual accuracy.
- Do not start with "here's an enhanced description". Just give the description.

Original Data:
{json.dumps(item_data, indent=2)}

Enhanced Description:"""

    payload = {
        "modelId": "arn:aws:bedrock:us-east-2:302263051966:inference-profile/us.anthropic.claude-3-5-haiku-20241022-v1:0",
        "contentType": "application/json",
        "accept": "application/json",
        "body": json.dumps({
            "anthropic_version": "bedrock-2023-05-31",
            "max_tokens": 150,
            "temperature": 0.2,
            "system": "You are a culinary assistant that enhances menu descriptions for better searchability while maintaining accuracy.",
            "messages": [
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": enhancement_prompt}
                    ]
                }
            ]
        })
    }

    try:
        response = bedrock_client.invoke_model(**payload)
        result = json.loads(response["body"].read().decode("utf-8"))
        return next(item["text"].strip() for item in result["content"] if item["type"] == "text")
    except Exception as e:
        print(f"Enhancement error: {e}")
        return item_data.get('menu_description', '')  # Fallback to original

def generate_enhanced_chunk(chunk, bedrock_client):
    enhanced_desc = enhance_description_with_llm(chunk['metadata'], bedrock_client)
    
    enhanced_text = (
        f"{chunk['metadata']['menu_item']} ({chunk['metadata']['menu_category']}) at {chunk['metadata']['restaurant_name']}. "
        f"Description: {enhanced_desc} "
        f"Ingredients: {', '.join(chunk['metadata']['ingredients'])}. "
        f"Pairings: {chunk['metadata'].get('pairings', 'Excellent with desserts or cheese boards')}. "
        f"Dietary: {chunk['metadata'].get('dietary', 'Contains alcohol' if 'wine' in chunk['metadata']['menu_category'].lower() else '')}. "
        f"Price: {chunk['metadata']['price_tier']}. Location: {chunk['metadata']['location']}"
    )
    
    return {
        "text": enhanced_text,
        "metadata": chunk["metadata"],
        "chunk_id": chunk["chunk_id"]
    }

# %%
df = pd.read_csv("Imputed_decription.csv").drop(["Unnamed: 0.1", "Unnamed: 0"], axis = 1)
df["categories"] = np.where(df["categories"].isna(), "Unknown", df["categories"])
df["rating"] = np.where(df["rating"].isna(), 0, df["rating"])
df["review_count"] = np.where(df["review_count"].isna(), 0, df["review_count"])
df["price"] = np.where(df["price"].isna(), "$", df["price"])

df = add_restaurant_id(df)

chunks = prepare_chunks(df)
len(chunks)
# Out:
# 10571

# %%
for i, chunk in enumerate(chunks):
    chunk["chunk_id"] = i

# %%
with open('chunks_new.pkl', 'rb') as f:
    chunks_enhanced = pickle.load(f)

# %%
start_idx = 1174

while start_idx < len(chunks):

    chunks_enhanced.append(generate_enhanced_chunk(chunks[start_idx], bedrock_client))
    print(start_idx, end =", ")
        
    if (start_idx + 1) %500 == 0:
        embeddings_enhanced_file = "enhancing_chunks_" + str(start_idx) + '.pkl'
        with open(embeddings_enhanced_file, 'wb') as f:
            pickle.dump(chunks_enhanced, f)

    start_idx+=1
# Out:
# 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1329, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1393, 1394, 1395, 1396, 1397, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1399, 1400, 1401, 1402, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1539, 1540, 1541, 1542, 1543,
# KeyboardInterrupt

# %%
with open("embeddings_enhanced_file_1543.pkl", 'wb') as f:
    pickle.dump(chunks_enhanced, f)

# %%
start_idx = 1544

while start_idx < len(chunks):

    chunks_enhanced.append(generate_enhanced_chunk(chunks[start_idx], bedrock_client))
    print(start_idx, end =", ")
        
    if ((start_idx + 1) %500) == 0:
        embeddings_enhanced_file = "enhancing_chunks_" + str(start_idx) + '.pkl'
        with open(embeddings_enhanced_file, 'wb') as f:
            pickle.dump(chunks_enhanced, f)
        print("Embedding file name: ", embeddings_enhanced_file)

    start_idx+=1
# Out:
# 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1664, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1956, 1957, 1958, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1960, 1961, 1962, 1963, 1964, 1965, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1967, 1968, 1969, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, Embedding file name:  enhancing_chunks_1999.pkl
# 2000, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2090, 2091, 2092, 2093, 2094, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2096, 2097, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117, 2118, 2119, 2120, 2121, 2122, 2123, 2124, 2125, 2126, 2127, 2128, 2129, 2130, 2131, 2132, 2133, 2134, 2135, 2136, 2137, 2138, 2139, 2140, 2141, 2142, 2143, 2144, 2145, 2146, 2147, 2148, 2149, 2150, 2151, 2152, 2153, 2154, 2155, 2156, 2157, 2158, 2159, 2160, 2161, 2162, 2163, 2164, 2165, 2166, 2167, 2168, 2169, 2170, 2171, 2172, 2173, 2174, 2175, 2176, 2177, 2178, 2179, 2180, 2181, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2183, 2184, 2185, 2186, 2187, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2189, 2190, 2191, 2192, 2193, 2194, 2195, 2196, 2197, 2198, 2199, 2200, 2201, 2202, 2203, 2204, 2205, 2206, 2207, 2208, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2210, 2211, 2212, 2213, 2214, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2223, 2224, 2225, 2226, 2227, 2228, 2229, 2230, 2231, 2232, 2233, 2234, 2235, 2236, 2237, 2238, 2239, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269, 2270, 2271, 2272, 2273, 2274, 2275, 2276, 2277, 2278, 2279, 2280, 2281, 2282, 2283, 2284, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2286, 2287, 2288, 2289, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299, 2300, 2301, 2302, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2322, 2323, 2324, 2325, 2326, 2327, 2328, 2329, 2330, 2331, 2332, 2333, 2334, 2335, 2336, 2337, 2338, 2339, 2340, 2341, 2342, 2343, 2344, 2345, 2346, 2347, 2348, 2349, 2350, 2351, 2352, 2353, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2355, 2356, 2357, 2358, 2359, 2360, 2361, 2362, 2363, 2364, 2365, 2366, 2367, 2368, 2369, 2370, 2371, 2372, 2373, 2374, 2375, 2376, 2377, 2378, 2379, 2380, 2381, 2382, 2383, 2384, 2385, 2386, 2387, 2388, 2389, 2390, 2391, 2392, 2393, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2395, 2396, 2397, 2398, 2399, 2400, 2401, 2402, 2403, 2404, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2406, 2407, 2408, 2409, 2410, 2411, 2412, 2413, 2414, 2415, 2416, 2417, 2418, 2419, 2420, 2421, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2423, 2424, 2425, 2426, 2427, 2428, 2429, 2430, 2431, 2432, 2433, 2434, 2435, 2436, 2437, 2438, 2439, 2440, 2441, 2442, 2443, 2444, 2445, 2446, 2447, 2448, 2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2459, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2461, 2462, 2463, 2464, 2465, 2466, 2467, 2468, 2469, 2470, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2472, 2473, 2474, 2475, 2476, 2477, 2478, 2479, 2480, 2481, 2482, 2483, 2484, 2485, 2486, 2487, 2488, 2489, 2490, 2491, 2492, 2493, 2494, 2495, 2496, 2497, 2498, 2499, Embedding file name:  enhancing_chunks_2499.pkl
# 2500, 2501, 2502, 2503, 2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514, 2515, 2516, 2517, 2518, 2519, 2520, 2521, 2522, 2523, 2524, 2525, 2526, 2527, 2528, 2529, 2530, 2531, 2532, 2533, 2534, 2535, 2536, 2537, 2538, 2539, 2540, 2541, 2542, 2543, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2545, 2546, 2547, 2548, 2549, 2550, 2551, 2552, 2553, 2554, 2555, 2556, 2557, 2558, 2559, 2560, 2561, 2562, 2563, 2564, 2565, 2566, 2567, 2568, 2569, 2570, 2571, 2572, 2573, 2574, 2575, 2576, 2577, 2578, 2579, 2580, 2581, 2582, 2583, 2584, 2585, 2586, 2587, 2588, 2589, 2590, 2591, 2592, 2593, 2594, 2595, 2596, 2597, 2598, 2599, 2600, 2601, 2602, 2603, 2604, 2605, 2606, 2607, 2608, 2609, 2610, 2611, 2612, 2613, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2615, 2616, 2617, 2618, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2620, 2621, 2622, 2623, 2624, 2625, 2626, 2627, 2628, 2629, 2630, 2631, 2632, 2633, 2634, 2635, 2636, 2637, 2638, 2639, 2640, 2641, 2642, 2643, 2644, 2645, 2646, 2647, 2648, 2649, 2650, 2651, 2652, 2653, 2654, 2655, 2656, 2657, 2658, 2659, 2660, 2661, 2662, 2663, 2664, 2665, 2666, 2667, 2668, 2669, 2670, 2671, 2672, 2673, 2674, 2675, 2676, 2677, 2678, 2679, 2680, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2682, 2683, 2684, 2685, 2686, 2687, 2688, 2689, 2690, 2691, 2692, 2693, 2694, 2695, 2696, 2697, 2698, 2699, 2700, 2701, 2702, 2703, 2704, 2705, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2707, 2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716, 2717, 2718, 2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727, 2728, 2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738, 2739, 2740, 2741, 2742, 2743, 2744, 2745, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2747, 2748, 2749, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2751, 2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783, 2784, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793, 2794, 2795, 2796, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2798, 2799, 2800, 2801, 2802, 2803, 2804, 2805, 2806, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2808, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2810, 2811, 2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936, 2937, 2938, 2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947, 2948, 2949, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958, 2959, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969, 2970, 2971, 2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980, 2981, 2982, 2983, 2984, 2985, 2986, 2987, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 2989, 2990, 2991, 2992, 2993, 2994, 2995, 2996, 2997, 2998, 2999, Embedding file name:  enhancing_chunks_2999.pkl
# 3000, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036, 3037, 3038, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3040, 3041, 3042, 3043, 3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3065, 3066, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3074, 3075, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3077, 3078, 3079, 3080, 3081, 3082, 3083, 3084, 3085, 3086, 3087, 3088, 3089, 3090, 3091, 3092, 3093, 3094, 3095, 3096, 3097, 3098, 3099, 3100, 3101, 3102, 3103, 3104, 3105, 3106, 3107, 3108, 3109, 3110, 3111, 3112, 3113, 3114, 3115, 3116, 3117, 3118, 3119, 3120, 3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128, 3129, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3131, 3132, 3133, 3134, 3135, 3136, 3137, 3138, 3139, 3140, 3141, 3142, 3143, 3144, 3145, 3146, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3148, 3149, 3150, 3151, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3153, 3154, 3155, 3156, 3157, 3158, 3159, 3160, 3161, 3162, 3163, 3164, 3165, 3166, 3167, 3168, 3169, 3170, 3171, 3172, 3173, 3174, 3175, 3176, 3177, 3178, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3180, 3181, 3182, 3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193, 3194, 3195, 3196, 3197, 3198, 3199, 3200, 3201, 3202, 3203, 3204, 3205, 3206, 3207, 3208, 3209, 3210, 3211, 3212, 3213, 3214, 3215, 3216, 3217, 3218, 3219, 3220, 3221, 3222, 3223, 3224, 3225, 3226, 3227, 3228, 3229, 3230, 3231, 3232, 3233, 3234, 3235, 3236, 3237, 3238, 3239, 3240, 3241, 3242, 3243, 3244, 3245, 3246, 3247, 3248, 3249, 3250, 3251, 3252, 3253, 3254, 3255, 3256, 3257, 3258, 3259, 3260, 3261, 3262, 3263, 3264, 3265, 3266, 3267, 3268, 3269, 3270, 3271, 3272, 3273, 3274, 3275, 3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283, 3284, 3285, 3286, 3287, 3288, 3289, 3290, 3291, 3292, 3293, 3294, 3295, 3296, 3297, 3298, 3299, 3300, 3301, 3302, 3303, 3304, 3305, 3306, 3307, 3308, 3309, 3310, 3311, 3312, 3313, 3314, 3315, 3316, 3317, 3318, 3319, 3320, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3322, 3323, 3324, 3325, 3326, 3327, 3328, 3329, 3330, 3331, 3332, 3333, 3334, 3335, 3336, 3337, 3338, 3339, 3340, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3342, 3343, 3344, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3346, 3347, 3348, 3349, 3350, 3351, 3352, 3353, 3354, 3355, 3356, 3357, 3358, 3359, 3360, 3361, 3362, 3363, 3364, 3365, 3366, 3367, 3368, 3369, 3370, 3371, 3372, 3373, 3374, 3375, 3376, 3377, 3378, 3379, 3380, 3381, 3382, 3383, 3384, 3385, 3386, 3387, 3388, 3389, 3390, 3391, 3392, 3393, 3394, 3395, 3396, 3397, 3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408, 3409, 3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419, 3420, 3421, 3422, 3423, 3424, 3425, 3426, 3427, 3428, 3429, 3430, 3431, 3432, 3433, 3434, 3435, 3436, 3437, 3438, 3439, 3440, 3441, 3442, 3443, 3444, 3445, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3447, 3448, 3449, 3450, 3451, 3452, 3453, 3454, 3455, 3456, 3457, 3458, 3459, 3460, 3461, 3462, 3463, 3464, 3465, 3466, 3467, 3468, 3469, 3470, 3471, 3472, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3474, 3475, 3476, 3477, 3478, 3479, 3480, 3481, 3482, 3483, 3484, 3485, 3486, 3487, 3488, 3489, 3490, 3491, 3492, 3493, 3494, 3495, 3496, 3497, 3498, 3499, Embedding file name:  enhancing_chunks_3499.pkl
# 3500, 3501, 3502, 3503, 3504, 3505, 3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 3514, 3515, 3516, 3517, 3518, 3519, 3520, 3521, 3522, 3523, 3524, 3525, 3526, 3527, 3528, 3529, 3530, 3531, 3532, 3533, 3534, 3535, 3536, 3537, 3538, 3539, 3540, 3541, 3542, 3543, 3544, 3545, 3546, 3547, 3548, 3549, 3550, 3551, 3552, 3553, 3554, 3555, 3556, 3557, 3558, 3559, 3560, 3561, 3562, 3563, 3564, 3565, 3566, 3567, 3568, 3569, 3570, 3571, 3572, 3573, 3574, 3575, 3576, 3577, 3578, 3579, 3580, 3581, 3582, 3583, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3585, 3586, 3587, 3588, 3589, 3590, 3591, 3592, 3593, 3594, 3595, 3596, 3597, 3598, 3599, 3600, 3601, 3602, 3603, 3604, 3605, 3606, 3607, 3608, 3609, 3610, 3611, 3612, 3613, 3614, 3615, 3616, 3617, 3618, 3619, 3620, 3621, 3622, 3623, 3624, 3625, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3627, 3628, 3629, 3630, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3632, 3633, 3634, 3635, 3636, 3637, 3638, 3639, 3640, 3641, 3642, 3643, 3644, 3645, 3646, 3647, 3648, 3649, 3650, 3651, 3652, 3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3666, 3667, 3668, 3669, 3670, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3672, 3673, 3674, 3675, 3676, 3677, 3678, 3679, 3680, 3681, 3682, 3683, 3684, 3685, 3686, 3687, 3688, 3689, 3690, 3691, 3692, 3693, 3694, 3695, 3696, 3697, 3698, 3699, 3700, 3701, 3702, 3703, 3704, 3705, 3706, 3707, 3708, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3710, 3711, 3712, 3713, 3714, 3715, 3716, 3717, 3718, 3719, 3720, 3721, 3722, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3724, 3725, 3726, 3727, 3728, 3729, 3730, 3731, 3732, 3733, 3734, 3735, 3736, 3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, 3753, 3754, 3755, 3756, 3757, 3758, 3759, 3760, 3761, 3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770, 3771, 3772, 3773, 3774, 3775, 3776, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3778, 3779, 3780, 3781, 3782, 3783, 3784, 3785, 3786, 3787, 3788, 3789, 3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797, 3798, 3799, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3801, 3802, 3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810, 3811, 3812, 3813, 3814, 3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825, 3826, 3827, 3828, 3829, 3830, 3831, 3832, 3833, 3834, 3835, 3836, 3837, 3838, 3839, 3840, 3841, 3842, 3843, 3844, 3845, 3846, 3847, 3848, 3849, 3850, 3851, 3852, 3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860, 3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868, 3869, 3870, 3871, 3872, 3873, 3874, 3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3884, 3885, 3886, 3887, 3888, 3889, 3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897, 3898, 3899, 3900, 3901, 3902, 3903, 3904, 3905, 3906, 3907, 3908, 3909, 3910, 3911, 3912, 3913, 3914, 3915, 3916, 3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924, 3925, 3926, 3927, 3928, 3929, 3930, 3931, 3932, 3933, 3934, 3935, 3936, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3938, 3939, 3940, 3941, 3942, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952, 3953, 3954, 3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963, 3964, 3965, 3966, 3967, 3968, 3969, 3970, 3971, 3972, 3973, 3974, 3975, 3976, 3977, 3978, 3979, 3980, 3981, 3982, 3983, 3984, 3985, 3986, 3987, 3988, 3989, 3990, 3991, 3992, 3993, 3994, 3995, 3996, 3997, 3998, 3999, Embedding file name:  enhancing_chunks_3999.pkl
# 4000, 4001, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4003, 4004, 4005, 4006, 4007, 4008, 4009, 4010, 4011, 4012, 4013, 4014, 4015, 4016, 4017, 4018, 4019, 4020, 4021, 4022, 4023, 4024, 4025, 4026, 4027, 4028, 4029, 4030, 4031, 4032, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4034, 4035, 4036, 4037, 4038, 4039, 4040, 4041, 4042, 4043, 4044, 4045, 4046, 4047, 4048, 4049, 4050, 4051, 4052, 4053, 4054, 4055, 4056, 4057, 4058, 4059, 4060, 4061, 4062, 4063, 4064, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4066, 4067, 4068, 4069, 4070, 4071, 4072, 4073, 4074, 4075, 4076, 4077, 4078, 4079, 4080, 4081, 4082, 4083, 4084, 4085, 4086, 4087, 4088, 4089, 4090, 4091, 4092, 4093, 4094, 4095, 4096, 4097, 4098, 4099, 4100, 4101, 4102, 4103, 4104, 4105, 4106, 4107, 4108, 4109, 4110, 4111, 4112, 4113, 4114, 4115, 4116, 4117, 4118, 4119, 4120, 4121, 4122, 4123, 4124, 4125, 4126, 4127, 4128, 4129, 4130, 4131, 4132, 4133, 4134, 4135, 4136, 4137, 4138, 4139, 4140, 4141, 4142, 4143, 4144, 4145, 4146, 4147, 4148, 4149, 4150, 4151, 4152, 4153, 4154, 4155, 4156, 4157, 4158, 4159, 4160, 4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168, 4169, 4170, 4171, 4172, 4173, 4174, 4175, 4176, 4177, 4178, 4179, 4180, 4181, 4182, 4183, 4184, 4185, 4186, 4187, 4188, 4189, 4190, 4191, 4192, 4193, 4194, 4195, 4196, 4197, 4198, 4199, 4200, 4201, 4202, 4203, 4204, 4205, 4206, 4207, 4208, 4209, 4210, 4211, 4212, 4213, 4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4222, 4223, 4224, 4225, 4226, 4227, 4228, 4229, 4230, 4231, 4232, 4233, 4234, 4235, 4236, 4237, 4238, 4239, 4240, 4241, 4242, 4243, 4244, 4245, 4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254, 4255, 4256, 4257, 4258, 4259, 4260, 4261, 4262, 4263, 4264, 4265, 4266, 4267, 4268, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4270, 4271, 4272, 4273, 4274, 4275, 4276, 4277, 4278, 4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293, 4294, 4295, 4296, 4297, 4298, 4299, 4300, 4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310, 4311, 4312, 4313, 4314, 4315, 4316, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349, 4350, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4352, 4353, 4354, 4355, 4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368, 4369, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4371, 4372, 4373, 4374, 4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382, 4383, 4384, 4385, 4386, 4387, 4388, 4389, 4390, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4392, 4393, 4394, 4395, 4396, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4398, 4399, 4400, 4401, 4402, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4404, 4405, 4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4414, 4415, 4416, 4417, 4418, 4419, 4420, 4421, 4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432, 4433, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4435, 4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443, 4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454, 4455, 4456, 4457, 4458, 4459, 4460, 4461, 4462, 4463, 4464, 4465, 4466, 4467, 4468, 4469, 4470, 4471, 4472, 4473, 4474, 4475, 4476, 4477, 4478, 4479, 4480, 4481, 4482, 4483, 4484, 4485, 4486, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4488, 4489, 4490, 4491, 4492, 4493, 4494, 4495, 4496, 4497, 4498, 4499, Embedding file name:  enhancing_chunks_4499.pkl
# 4500, 4501, 4502, 4503, 4504, 4505, 4506, 4507, 4508, 4509, 4510, 4511, 4512, 4513, 4514, 4515, 4516, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4518, 4519, 4520, 4521, 4522, 4523, 4524, 4525, 4526, 4527, 4528, 4529, 4530, 4531, 4532, 4533, 4534, 4535, 4536, 4537, 4538, 4539, 4540, 4541, 4542, 4543, 4544, 4545, 4546, 4547, 4548, 4549, 4550, 4551, 4552, 4553, 4554, 4555, 4556, 4557, 4558, 4559, 4560, 4561, 4562, 4563, 4564, 4565, 4566, 4567, 4568, 4569, 4570, 4571, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4573, 4574, 4575, 4576, 4577, 4578, 4579, 4580, 4581, 4582, 4583, 4584, 4585, 4586, 4587, 4588, 4589, 4590, 4591, 4592, 4593, 4594, 4595, 4596, 4597, 4598, 4599, 4600, 4601, 4602, 4603, 4604, 4605, 4606, 4607, 4608, 4609, 4610, 4611, 4612, 4613, 4614, 4615, 4616, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4618, 4619, 4620, 4621, 4622, 4623, 4624, 4625, 4626, 4627, 4628, 4629, 4630, 4631, 4632, 4633, 4634, 4635, 4636, 4637, 4638, 4639, 4640, 4641, 4642, 4643, 4644, 4645, 4646, 4647, 4648, 4649, 4650, 4651, 4652, 4653, 4654, 4655, 4656, 4657, 4658, 4659, 4660, 4661, 4662, 4663, 4664, 4665, 4666, 4667, 4668, 4669, 4670, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4672, 4673, 4674, 4675, 4676, 4677, 4678, 4679, 4680, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4682, 4683, 4684, 4685, 4686, 4687, 4688, 4689, 4690, 4691, 4692, 4693, 4694, 4695, 4696, 4697, 4698, 4699, 4700, 4701, 4702, 4703, 4704, 4705, 4706, 4707, 4708, 4709, 4710, 4711, 4712, 4713, 4714, 4715, 4716, 4717, 4718, 4719, 4720, 4721, 4722, 4723, 4724, 4725, 4726, 4727, 4728, 4729, 4730, 4731, 4732, 4733, 4734, 4735, 4736, 4737, 4738, 4739, 4740, 4741, 4742, 4743, 4744, 4745, 4746, 4747, 4748, 4749, 4750, 4751, 4752, 4753, 4754, 4755, 4756, 4757, 4758, 4759, 4760, 4761, 4762, 4763, 4764, 4765, 4766, 4767, 4768, 4769, 4770, 4771, 4772, 4773, 4774, 4775, 4776, 4777, 4778, 4779, 4780, 4781, 4782, 4783, 4784, 4785, 4786, 4787, 4788, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4790, 4791, 4792, 4793, 4794, 4795, 4796, 4797, 4798, 4799, 4800, 4801, 4802, 4803, 4804, 4805, 4806, 4807, 4808, 4809, 4810, 4811, 4812, 4813, 4814, 4815, 4816, 4817, 4818, 4819, 4820, 4821, 4822, 4823, 4824, 4825, 4826, 4827, 4828, 4829, 4830, 4831, 4832, 4833, 4834, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4836, 4837, 4838, 4839, 4840, 4841, 4842, 4843, 4844, 4845, 4846, 4847, 4848, 4849, 4850, 4851, 4852, 4853, 4854, 4855, 4856, 4857, 4858, 4859, 4860, 4861, 4862, 4863, 4864, 4865, 4866, 4867, 4868, 4869, 4870, 4871, 4872, 4873, 4874, 4875, 4876, 4877, 4878, 4879, 4880, 4881, 4882, 4883, 4884, 4885, 4886, 4887, 4888, 4889, 4890, 4891, 4892, 4893, 4894, 4895, 4896, 4897, 4898, 4899, 4900, 4901, 4902, 4903, 4904, 4905, 4906, 4907, 4908, 4909, 4910, 4911, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4913, 4914, 4915, 4916, 4917, 4918, 4919, 4920, 4921, 4922, 4923, 4924, 4925, 4926, 4927, 4928, 4929, 4930, 4931, 4932, 4933, 4934, 4935, 4936, 4937, 4938, 4939, 4940, 4941, 4942, 4943, 4944, 4945, 4946, 4947, 4948, 4949, 4950, 4951, 4952, 4953, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4955, 4956, 4957, 4958, 4959, 4960, 4961, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 4963, 4964, 4965, 4966, 4967, 4968, 4969, 4970, 4971, 4972, 4973, 4974, 4975, 4976, 4977, 4978, 4979, 4980, 4981, 4982, 4983, 4984, 4985, 4986, 4987, 4988, 4989, 4990, 4991, 4992, 4993, 4994, 4995, 4996, 4997, 4998, 4999, Embedding file name:  enhancing_chunks_4999.pkl
# 5000, 5001, 5002, 5003, 5004, 5005, 5006, 5007, 5008, 5009, 5010, 5011, 5012, 5013, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 5015, 5016, 5017, 5018, 5019, 5020, 5021, 5022, 5023, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 5025, 5026, 5027, 5028, 5029, 5030, 5031, 5032, 5033, 5034, 5035, 5036, 5037, 5038, 5039, 5040, 5041, 5042, 5043, 5044, 5045, 5046, 5047, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 5049, 5050, 5051, 5052, 5053, 5054, 5055, 5056, 5057, 5058, 5059, 5060, 5061, 5062, 5063, 5064, 5065, 5066, 5067, 5068, 5069, 5070, 5071, 5072, 5073, 5074, 5075, 5076, 5077, 5078, 5079, 5080, 5081, 5082, 5083, 5084, 5085, 5086, 5087, 5088, 5089, 5090, 5091, 5092, 5093, 5094, 5095, 5096, 5097, 5098, 5099, 5100, 5101, 5102, 5103, 5104, 5105, 5106, 5107, 5108, 5109, 5110, 5111, 5112, 5113, 5114, 5115, Enhancement error: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# 5117, 5118, 5119, 5120, 5121, 5122, 5123, 5124, 5125, 5126, 5127, 5128, 5129, 5130, 5131, 5132, 5133, 5134, 5135, 5136, 5137, 5138, 5139, 5140, 5141, 5142, 5143, 5144, 5145, 5146, 5147, 5148, 5149,

# %% [markdown]
# > We were able to do 7500 chunks. Thats nearly 75% data

# %%
with open('enhancing_chunks_7499.pkl', 'rb') as f:
    enhanced_chunks_7500 = pickle.load(f)

# %%
enhanced_chunks_7500 = [chunk["text"] for chunk in enhanced_chunks_7500]
enhanced_chunk_embeddings_7500 = get_titan_embeddings(enhanced_chunks_7500)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000

# %%
with open('enhanced_chunk_embeddings_7500.pkl', 'wb') as f:
    pickle.dump(enhanced_chunk_embeddings_7500, f)

with open('enhanced_chunk_embeddings_7500.pkl', 'rb') as f:
    enhanced_chunk_embeddings_7500_loaded = pickle.load(f)

# %%
with open('enhanced_chunk_embeddings_7500.pkl', 'rb') as f:
    enhanced_chunk_embeddings_7500_loaded = pickle.load(f)

# %%
chunk_copy = chunks[:7500].copy()

# %%
for idx, chunk in enumerate(chunk_copy):
    chunk_copy[idx]["text"] = enhanced_chunks_7500[idx]

# %%
with open('chunk_copy.pkl', 'wb') as f:
    pickle.dump(chunk_copy, f)

with open('chunk_copy.pkl', 'rb') as f:
    chunk_copy = pickle.load(f)

# %%
with open('chunk_copy.pkl', 'rb') as f:
    chunk_copy = pickle.load(f)

# %%
# Out:
# [{'text': {'text': "passagem porto (Dessert Wine) at 20 spot. Description: A luxurious Portuguese ruby port from the Douro Valley, the Passagem Porto offers a rich, velvety texture with deep notes of dark chocolate, caramel, and subtle almond nuances. Ideal for post-dinner indulgence, this medium-bodied dessert wine beautifully complements dark chocolate truffles, aged blue cheeses, and walnut-based desserts. Gluten-free and naturally sweet, it's perfect for intimate gatherings or as a sophisticated nightcap. Traditionally crafted using indigenous Portuguese grape varieties, this port represents centuries of winemaking heritage from the world's oldest demarcated wine region. Best served slightly chilled at 60- Ingredients: port. Pairings: Excellent with desserts or cheese boards. Dietary: Contains alcohol. Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Dessert Wine',
#     'menu_description': 'rich velvety port with hints of dark chocolate caramel and a subtle nutty undertone perfect for sipping on its own or pairing with decadent desserts',
#     'menu_item': 'passagem porto',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['port'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932108},
#    'chunk_id': 0},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Dessert Wine',
#    'menu_description': 'rich velvety port with hints of dark chocolate caramel and a subtle nutty undertone perfect for sipping on its own or pairing with decadent desserts',
#    'menu_item': 'passagem porto',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['port'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932108},
#   'chunk_id': 0},
#  {'text': {'text': 'maple roasted nuts (Snacks) at 20 spot. Description: Artisanal maple-glazed mixed nuts, delicately roasted to achieve a golden, crisp exterior and a rich, buttery interior, offering a harmonious balance of sweet maple complexity and savory sea salt crunch. These California-inspired bar snacks draw from New American culinary traditions, featuring a medley of locally sourced nuts like almonds, pecans, and walnuts that pair exquisitely with robust red wines or craft cocktails. Naturally gluten-free and vegan-friendly, these nuts provide a sophisticated, protein-rich nibble perfect for wine tastings, cocktail hours, or as an elegant charcuterie accompaniment. The maple roasting technique, remin Ingredients: sea salt, nuts, maple. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Snacks',
#     'menu_description': 'sea salt',
#     'menu_item': 'maple roasted nuts',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['sea salt', 'nuts', 'maple'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932109},
#    'chunk_id': 1},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Snacks',
#    'menu_description': 'sea salt',
#    'menu_item': 'maple roasted nuts',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['sea salt', 'nuts', 'maple'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932109},
#   'chunk_id': 1},
#  {'text': {'text': "castelvetrano olives (Snacks) at 20 spot. Description: Vibrant Castelvetrano olives, renowned for their buttery, bright green hue and creamy texture, are delicately infused with aromatic rosemary and a subtle kick of chili flake. These Sicilian olives offer a mild, fruity flavor profile with a crisp, meaty bite, perfect as a zesty wine bar appetizer or charcuterie accompaniment. Ideal for Mediterranean-inspired small plates, they pair beautifully with crisp white wines or sparkling aperitifs, and are naturally vegan and gluten-free. The dish reflects California's New American cuisine ethos of simple, ingredient-forward preparations that highlight pure, bold flavors. Ingredients: castelvetrano olives, chili flake, rosemary. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Snacks',
#     'menu_description': 'citrus rosemary chili flake',
#     'menu_item': 'castelvetrano olives',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['castelvetrano olives', 'chili flake', 'rosemary'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932110},
#    'chunk_id': 2},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Snacks',
#    'menu_description': 'citrus rosemary chili flake',
#    'menu_item': 'castelvetrano olives',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['castelvetrano olives', 'chili flake', 'rosemary'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932110},
#   'chunk_id': 2},
#  {'text': {'text': 'house bread (Snacks) at 20 spot. Description: Artisanal house-baked bread lavishly spread with silky, vibrant cherry-infused butter—a delicate balance of sweet-tart fruit and rich, creamy dairy. Crafted in the style of contemporary New American cuisine, this rustic bread accompaniment offers a delightful textural contrast with its crisp exterior and tender crumb, complemented by the smooth, fruity butter. Ideal as a wine bar appetizer or shared small plate, it pairs beautifully with light, crisp white wines or sparkling rosé. Perfect for vegetarian diners, this seasonal interpretation showcases local San Francisco culinary creativity. Best enjoyed warm, with the cherry butter melting g Ingredients: cherry, butter. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Snacks',
#     'menu_description': 'cherry butter',
#     'menu_item': 'house bread',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['cherry', 'butter'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932111},
#    'chunk_id': 3},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Snacks',
#    'menu_description': 'cherry butter',
#    'menu_item': 'house bread',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['cherry', 'butter'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932111},
#   'chunk_id': 3},
#  {'text': {'text': "cheese (Boards) at 20 spot. Description: A luxurious artisan cheese board featuring a delicate shredded cheese blend with sweet alyssum notes, complemented by vibrant raspberry jam and a delightful crunch of toasted nuts. Served on crisp crostini, this New American-style appetizer offers a harmonious balance of creamy, tangy, and sweet flavors perfect for wine pairing or sophisticated small plate dining. Naturally gluten-light with vegetarian-friendly ingredients, this board provides a sensory journey through textural contrasts and nuanced flavor profiles typical of California wine bar cuisine. Best enjoyed with a crisp white wine or light-bodied red, this cheese selection celebrates the Bay Area's artisanal Ingredients: raspberry jam, cheese, toasted nuts, crostini. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Boards',
#     'menu_description': 'shredder c sweet alyssum s three trick pony g raspberry jam toasted nuts crostini',
#     'menu_item': 'cheese',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['raspberry jam', 'cheese', 'toasted nuts', 'crostini'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932112},
#    'chunk_id': 4},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Boards',
#    'menu_description': 'shredder c sweet alyssum s three trick pony g raspberry jam toasted nuts crostini',
#    'menu_item': 'cheese',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['raspberry jam', 'cheese', 'toasted nuts', 'crostini'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932112},
#   'chunk_id': 4},
#  {'text': {'text': 'chicken liver mousse (Boards) at 20 spot. Description: Silky, rich chicken liver mousse whipped to a luxurious, velvety texture, offering a deep, earthy flavor profile balanced by bright, tangy pickled cherries. Served on crisp, golden-toasted artisan bread, this classic French-inspired New American appetizer delivers a sophisticated blend of creamy and acidic notes perfect for wine pairing. Ideal as a charcuterie board centerpiece or elegant starter, the dish showcases traditional French technique with a California wine country twist. Naturally gluten-free when served without bread, this protein-rich mousse is an indulgent small plate that highlights the nuanced flavors of carefully prepared offal. Best enjoyed with Ingredients: bread, cherries, chicken liver. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Boards',
#     'menu_description': 'pickled cherries toasted bread',
#     'menu_item': 'chicken liver mousse',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['bread', 'cherries', 'chicken liver'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932113},
#    'chunk_id': 5},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Boards',
#    'menu_description': 'pickled cherries toasted bread',
#    'menu_item': 'chicken liver mousse',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['bread', 'cherries', 'chicken liver'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932113},
#   'chunk_id': 5},
#  {'text': {'text': "local halibut crudo (Small Plates) at 20 spot. Description: Delicate slices of pristine local halibut, kissed by a vibrant cilantro and serrano chile broth, showcase a bright, oceanic crudo with a subtle heat and refreshing Korean melon undertones. This New American-style raw fish preparation offers a delicate, silky texture with a zesty, herbaceous profile that pairs beautifully with crisp white wines like Albariño or a light, mineral-driven Sauvignon Blanc. Perfect as an elegant appetizer or light summer dish, the dish highlights California's coastal seafood tradition with its clean, nuanced flavors and is naturally gluten-free and low-carb. The interplay of cool, Ingredients: serrano chile, halibut, broth, korean melon, cilantro. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'cilantro serrano chile broth korean melon',
#     'menu_item': 'local halibut crudo',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['serrano chile',
#      'halibut',
#      'broth',
#      'korean melon',
#      'cilantro'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932114},
#    'chunk_id': 6},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'cilantro serrano chile broth korean melon',
#    'menu_item': 'local halibut crudo',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['serrano chile',
#     'halibut',
#     'broth',
#     'korean melon',
#     'cilantro'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932114},
#   'chunk_id': 6},
#  {'text': {'text': "green beans (Small Plates) at 20 spot. Description: Crisp, vibrant green beans tossed with sun-ripened Early Girl tomatoes and sweet bell peppers, offering a bright, garden-fresh crunch with a delicate sweetness. This New American small plate showcases California's seasonal produce, perfectly complementing light white wines or rosés and ideal as a refreshing side or shared appetizer. Naturally gluten-free and vegan, the dish highlights the region's farm-to-table ethos, with a light, herbaceous profile that pairs beautifully with grilled proteins or as part of a summer mezze spread. The combination of tender-crisp green beans and juicy tomatoes creates a harmonious blend of textures and flavors Ingredients: early girl tomatoes, sweet peppers, green beans. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'early girl tomatoes sweet peppers',
#     'menu_item': 'green beans',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['early girl tomatoes', 'sweet peppers', 'green beans'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932115},
#    'chunk_id': 7},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'early girl tomatoes sweet peppers',
#    'menu_item': 'green beans',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['early girl tomatoes', 'sweet peppers', 'green beans'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932115},
#   'chunk_id': 7},
#  {'text': {'text': "marinated cucumbers (Small Plates) at 20 spot. Description: Crisp, cool marinated cucumbers dressed with fragrant za'atar and toasted sesame, featuring bright cherry tomatoes and delicate purslane leaves for a refreshing Mediterranean-inspired small plate. The dish offers a light, herbaceous crunch with nutty undertones, perfect as a vibrant summer appetizer or elegant wine bar accompaniment. Naturally vegan and gluten-free, this New American interpretation highlights fresh, seasonal produce with Middle Eastern spice influences, ideal for pairing with crisp white wines or as a palate-cleansing side. The za'atar blend—traditionally combining dried herbs, sumac, and sesame seeds—adds a complex, tangy dimension to Ingredients: cherry tomato, purslane, cucumber, sesame, zaatar. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'cherry tomatoes purslane zaatar sesame dressing',
#     'menu_item': 'marinated cucumbers',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['cherry tomato',
#      'purslane',
#      'cucumber',
#      'sesame',
#      'zaatar'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932116},
#    'chunk_id': 8},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'cherry tomatoes purslane zaatar sesame dressing',
#    'menu_item': 'marinated cucumbers',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['cherry tomato',
#     'purslane',
#     'cucumber',
#     'sesame',
#     'zaatar'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932116},
#   'chunk_id': 8},
#  {'text': {'text': 'heirloom beans (Small Plates) at 20 spot. Description: Rustic heirloom beans drizzled with robust Sicilian olive oil, featuring delicate slices of vibrant watermelon radish that add a crisp, peppery crunch and jewel-like visual appeal. These tender, creamy legumes showcase a classic New American farm-to-table approach, offering a nuanced, earthy flavor profile with bright, herbaceous undertones. Perfectly paired with a crisp white wine or as a sophisticated side dish, this small plate is naturally gluten-free and vegan, ideal for health-conscious diners seeking clean, minimalist cuisine. The dish draws inspiration from Mediterranean culinary traditions, where simple, high-quality ingredients are celebrated for Ingredients: sicilian olive oil, watermelon radish, heirloom beans. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'watermelon radish sicilian olive oil',
#     'menu_item': 'heirloom beans',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['sicilian olive oil',
#      'watermelon radish',
#      'heirloom beans'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932117},
#    'chunk_id': 9},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'watermelon radish sicilian olive oil',
#    'menu_item': 'heirloom beans',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['sicilian olive oil',
#     'watermelon radish',
#     'heirloom beans'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932117},
#   'chunk_id': 9},
#  {'text': {'text': "stone fruit salad (Small Plates) at 20 spot. Description: A vibrant New American stone fruit salad featuring creamy burrata nestled alongside juicy, sun-ripened peaches and nectarines, drizzled with a rich walnut pesto that offers nutty depth and herbaceous complexity. The dish balances silky cheese textures with crisp fruit and crunchy walnut fragments, creating a harmonious summer-inspired composition perfect for warm evenings or as an elegant wine bar appetizer. Vegetarian-friendly and gluten-free, this salad pairs beautifully with crisp white wines like Sauvignon Blanc or a light Pinot Grigio, highlighting California's farm-to-table culinary ethos and seasonal produce Ingredients: pesto, stone fruit, walnuts, burrata. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'burrata walnut pesto',
#     'menu_item': 'stone fruit salad',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['pesto', 'stone fruit', 'walnuts', 'burrata'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932118},
#    'chunk_id': 10},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'burrata walnut pesto',
#    'menu_item': 'stone fruit salad',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['pesto', 'stone fruit', 'walnuts', 'burrata'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932118},
#   'chunk_id': 10},
#  {'text': {'text': "chilled watermelon (Small Plates) at 20 spot. Description: Crisp, juicy watermelon cubes kissed with vibrant lime and a subtle chile heat, nestled among delicate chrysanthemum greens and crunchy snap peas. This refreshing New American small plate offers a bright, cooling sensory experience with a delicate balance of sweet, tangy, and mildly spicy notes—perfect as a summer appetizer or palate cleanser. Ideal for wine pairing, particularly with a crisp rosé or light white wine, and suitable for vegan and gluten-free diets. The dish draws inspiration from California's innovative culinary scene, blending local produce with contemporary plating techniques that highlight fresh, seasonal ingredients. Best enjoye Ingredients: watermelon, chrysanthemum greens, snap peas, lime, chile. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'chrysanthemum greens snap peas lime chile',
#     'menu_item': 'chilled watermelon',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['watermelon',
#      'chrysanthemum greens',
#      'snap peas',
#      'lime',
#      'chile'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932119},
#    'chunk_id': 11},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'chrysanthemum greens snap peas lime chile',
#    'menu_item': 'chilled watermelon',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['watermelon',
#     'chrysanthemum greens',
#     'snap peas',
#     'lime',
#     'chile'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932119},
#   'chunk_id': 11},
#  {'text': {'text': "sweet corn salad (Small Plates) at 20 spot. Description: A vibrant sweet corn salad featuring crisp arrowhead cabbage and luscious mission figs, dressed with smoky, nutty salsa macha. The dish offers a delightful textural contrast between the tender corn kernels and crunchy cabbage, with a complex flavor profile balancing sweet, earthy, and subtly spicy notes. Ideal as a refreshing summer side or light lunch, this New American creation pairs beautifully with crisp white wines or light rosés. Perfect for vegetarian and gluten-free diners, the salad celebrates California's seasonal produce with a modern, wine bar-inspired twist. Best enjoyed al fresco or as a sophisticated small plate that showc Ingredients: mission figs, arrowhead cabbage, sweet corn, salsa macha. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Small Plates',
#     'menu_description': 'arrowhead cabbage mission figs salsa macha',
#     'menu_item': 'sweet corn salad',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['mission figs',
#      'arrowhead cabbage',
#      'sweet corn',
#      'salsa macha'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932120},
#    'chunk_id': 12},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Small Plates',
#    'menu_description': 'arrowhead cabbage mission figs salsa macha',
#    'menu_item': 'sweet corn salad',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['mission figs',
#     'arrowhead cabbage',
#     'sweet corn',
#     'salsa macha'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932120},
#   'chunk_id': 12},
#  {'text': {'text': "corn (Pizza) at 20 spot. Description: Rustic Corn Pizza: A delicate, wood-fired flatbread adorned with sweet roasted corn kernels, melted nutty Gruyère, and aromatic herbs. Creamy garlic-infused base provides a silky texture, while earthy sautéed mushrooms and bright green onions create a harmonious flavor profile. Ideal for vegetarian wine pairing or as a sophisticated small plate, this New American-style pizza captures California's farm-to-table ethos. Best enjoyed with a crisp white wine or light-bodied natural wine, highlighting the pizza's delicate herbal and umami notes. Gluten-free and vegetarian-friendly option available Ingredients: cream, garlic, basil, green onions, gruyere, mushrooms. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Pizza',
#     'menu_description': 'mushrooms green onions garlic cream basil gruyere',
#     'menu_item': 'corn',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['cream',
#      'garlic',
#      'basil',
#      'green onions',
#      'gruyere',
#      'mushrooms'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932121},
#    'chunk_id': 13},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Pizza',
#    'menu_description': 'mushrooms green onions garlic cream basil gruyere',
#    'menu_item': 'corn',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['cream',
#     'garlic',
#     'basil',
#     'green onions',
#     'gruyere',
#     'mushrooms'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932121},
#   'chunk_id': 13},
#  {'text': {'text': "garlic sausage (Pizza) at 20 spot. Description: A rustic New American pizza featuring robust garlic sausage nestled on a vibrant red sauce, with tender zucchini ribbons and briny capers creating a complex flavor profile. Crisp yet chewy crust supports layers of melted mozzarella, delivering a savory Mediterranean-inspired experience that balances rich, tangy, and herbaceous notes. Pairs beautifully with a crisp white wine or light-bodied red, ideal for casual dining or wine bar appetizers. Vegetarian-friendly modifications available; naturally gluten-conscious with potential low-carb adaptations. Rooted in San Francisco's innovative culinary landscape, this pizza represents the city's contemporary approach Ingredients: mozzarella, garlic sausage, capers, red sauce, zucchini. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Pizza',
#     'menu_description': 'red sauce zucchini capers mozzarella',
#     'menu_item': 'garlic sausage',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['mozzarella',
#      'garlic sausage',
#      'capers',
#      'red sauce',
#      'zucchini'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932122},
#    'chunk_id': 14},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Pizza',
#    'menu_description': 'red sauce zucchini capers mozzarella',
#    'menu_item': 'garlic sausage',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['mozzarella',
#     'garlic sausage',
#     'capers',
#     'red sauce',
#     'zucchini'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932122},
#   'chunk_id': 14},
#  {'text': {'text': 'braised oxtails (Mains) at 20 spot. Description: Tender, fall-off-the-bone braised oxtails bathed in a vibrant, sun-kissed sungold tomato sauce, punctuated by smoky, blistered shishito peppers that add a gentle heat and grassy complexity. This New American dish celebrates rich, slow-cooked meat with bright, seasonal California produce, perfect for pairing with a medium-bodied red wine or crisp craft beer. Naturally gluten-free and protein-rich, the dish offers a luxurious yet rustic dining experience that honors traditional braising techniques while showcasing contemporary San Francisco culinary creativity. Best enjoyed in a convivial wine bar setting or as a hearty share Ingredients: sauce, sungold tomato, shishito peppers, braised oxtails. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Mains',
#     'menu_description': 'sungold tomato sauce shishito peppers',
#     'menu_item': 'braised oxtails',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['sauce',
#      'sungold tomato',
#      'shishito peppers',
#      'braised oxtails'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932123},
#    'chunk_id': 15},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Mains',
#    'menu_description': 'sungold tomato sauce shishito peppers',
#    'menu_item': 'braised oxtails',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['sauce',
#     'sungold tomato',
#     'shishito peppers',
#     'braised oxtails'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932123},
#   'chunk_id': 15},
#  {'text': {'text': 'blueberry galette (Dessert) at 20 spot. Description: A rustic, free-form French-inspired pastry bursting with ripe, locally-sourced blueberries nestled in a buttery, flaky crust and crowned with delicate, cloud-like chantilly cream. The galette offers a harmonious balance of sweet-tart berries and rich, golden pastry with a tender, crumbly texture that melts effortlessly on the tongue. Perfectly paired with a crisp Riesling or light dessert wine, this New American interpretation of a classic French dessert is ideal for summer gatherings or as an elegant finale to a wine bar tasting menu. Vegetarian-friendly and featuring seasonal California produce, the blue Ingredients: cream, sugar, butter, pastry, blueberry. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Dessert',
#     'menu_description': 'chantilly cream',
#     'menu_item': 'blueberry galette',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['cream', 'sugar', 'butter', 'pastry', 'blueberry'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932124},
#    'chunk_id': 16},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Dessert',
#    'menu_description': 'chantilly cream',
#    'menu_item': 'blueberry galette',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['cream', 'sugar', 'butter', 'pastry', 'blueberry'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932124},
#   'chunk_id': 16},
#  {'text': {'text': "tres leches cake (Dessert) at 20 spot. Description: A luxuriously moist Latin American classic, this tres leches cake is a silky, cream-soaked delicacy featuring three milks (evaporated, condensed, and heavy cream) that create a decadently tender crumb. Topped with a vibrant apricot compote offering bright, tangy notes that cut through the cake's rich sweetness, this dessert balances delicate texture with intense flavor. Perfectly paired with a crisp late-harvest Riesling or a smooth espresso, it's an ideal finale to a meal or a celebratory treat that honors traditional Mexican culinary heritage. Vegetarian-friendly and gluten-free options available upon request. Best Ingredients: cream, tres leches cake, sugar, milk, apricot. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Dessert',
#     'menu_description': 'apricot compote',
#     'menu_item': 'tres leches cake',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['cream', 'tres leches cake', 'sugar', 'milk', 'apricot'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932125},
#    'chunk_id': 17},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Dessert',
#    'menu_description': 'apricot compote',
#    'menu_item': 'tres leches cake',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['cream', 'tres leches cake', 'sugar', 'milk', 'apricot'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932125},
#   'chunk_id': 17},
#  {'text': {'text': "paul dethune ambonnay grand cru brut champagne (Sparkling) at 20 spot. Description: Paul Dethune Ambonnay Grand Cru Brut Champagne: A luxurious Champagne from the prestigious Ambonnay terroir, offering delicate golden bubbles with an elegant bouquet of toasted brioche, ripe green apple, and bright citrus zest. Its crisp minerality and refined effervescence make it an exquisite aperitif or perfect pairing with oysters, soft cheeses, and light seafood canapés. Crafted using traditional Champenoise methods in the heart of France's Champagne region, this Grand Cru represents the pinnacle of Pinot Noir-driven sparkling wines, ideal for celebrations Ingredients: paul dethune ambonnay grand cru brut champagne. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Sparkling',
#     'menu_description': 'fine elegant bubbles dance on the palate with notes of toasted brioche apple and a hint of citrus finishing with a crisp refreshing minerality',
#     'menu_item': 'paul dethune ambonnay grand cru brut champagne',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['paul dethune ambonnay grand cru brut champagne'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932126},
#    'chunk_id': 18},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Sparkling',
#    'menu_description': 'fine elegant bubbles dance on the palate with notes of toasted brioche apple and a hint of citrus finishing with a crisp refreshing minerality',
#    'menu_item': 'paul dethune ambonnay grand cru brut champagne',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['paul dethune ambonnay grand cru brut champagne'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932126},
#   'chunk_id': 18},
#  {'text': {'text': 'paladin sparkilng red raboso fiore (Sparkling) at 20 spot. Description: A vibrant Venetian sparkling red wine with a jewel-like ruby color, offering an exuberant bouquet of ripe cherries and plump plums, delicately perfumed with rose petal aromatics. This crisp, lively Raboso Fiore from the Veneto region pairs beautifully with charcuterie, aged hard cheeses, and rich antipasti, making it an ideal aperitif or companion to rustic Italian small plates. Naturally gluten-free and vegan-friendly, this wine showcases the historic winemaking traditions of northeastern Italy, where indigenous grape varieties like Raboso have been cultivated for centuries. Its bright acidity Ingredients: raboso fiore. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Sparkling',
#     'menu_description': 'a glass of paladin sparkling red raboso fiore bursting with juicy cherry and plum flavors hints of rose petal and a crisp refreshing finish',
#     'menu_item': 'paladin sparkilng red raboso fiore',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['raboso fiore'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932127},
#    'chunk_id': 19},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Sparkling',
#    'menu_description': 'a glass of paladin sparkling red raboso fiore bursting with juicy cherry and plum flavors hints of rose petal and a crisp refreshing finish',
#    'menu_item': 'paladin sparkilng red raboso fiore',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['raboso fiore'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932127},
#   'chunk_id': 19},
#  {'text': {'text': "vorspannhof mayr grüner veltliner (White) at 20 spot. Description: Vorspannhof Mayr Grüner Veltliner: A vibrant Austrian white wine with a crisp, zesty profile featuring bright green apple notes, delicate white pepper spice, and a distinctive mineral undertone. Ideal for pairing with light seafood, fresh goat cheese, or asparagus-based dishes, this mid-weight wine showcases the signature grape of Austria's wine regions. Perfect for summer evenings or as an aperitif, it offers a refreshing and nuanced drinking experience that captures the elegant terroir of Lower Austria's wine country. Vegetarian and vegan-friendly, with low tannins and a clean, palate-cleans Ingredients: grüner veltliner. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'White',
#     'menu_description': 'a crisp glass of grüner veltliner bursting with green apple white pepper and a hint of minerality',
#     'menu_item': 'vorspannhof mayr grüner veltliner',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['grüner veltliner'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932128},
#    'chunk_id': 20},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'White',
#    'menu_description': 'a crisp glass of grüner veltliner bursting with green apple white pepper and a hint of minerality',
#    'menu_item': 'vorspannhof mayr grüner veltliner',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['grüner veltliner'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932128},
#   'chunk_id': 20},
#  {'text': {'text': "sziegl pince jonas olaszrizling blend (White) at 20 spot. Description: A vibrant Hungarian white wine crafted from Olaszrizling grapes, offering a crisp, mineral-driven profile with bright green apple and citrus notes. Delicately balanced with a refreshing acidity, this wine pairs beautifully with light seafood, goat cheese appetizers, and herb-forward dishes. Ideal for summer dining or as an aperitif, it showcases the elegant terroir of Hungary's cool-climate wine regions. Gluten-free and vegan-friendly, this mid-tier wine represents the emerging craft wine movement in New American cuisine. Best served chilled at 45-50°F to highlight its nuanced aromatics and clean, zesty finish. Ingredients: olaszrizling. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'White',
#     'menu_description': 'a crisp and refreshing blend of olaszrizling with hints of green apple citrus and a subtle minerality perfect for pairing with our seasonal small plates',
#     'menu_item': 'sziegl pince jonas olaszrizling blend',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['olaszrizling'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932132},
#    'chunk_id': 21},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'White',
#    'menu_description': 'a crisp and refreshing blend of olaszrizling with hints of green apple citrus and a subtle minerality perfect for pairing with our seasonal small plates',
#    'menu_item': 'sziegl pince jonas olaszrizling blend',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['olaszrizling'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932132},
#   'chunk_id': 21},
#  {'text': {'text': "idlewild flora  fauna dolcettogrignolinonebbiolo (Rosè) at 20 spot. Description: A vibrant Piedmontese rosé blend that captures the essence of Northern Italian winemaking, this delicate wine harmonizes Dolcetto's plush red fruit, Grignolino's bright acidity, and Nebbiolo's elegant earthiness. Pale salmon-pink in color with an aromatic bouquet of wild rose, fresh cherries, and subtle alpine herbs, it offers a silky texture and nuanced palate of red berries, dried herbs, and a mineral-driven finish. Perfectly paired with charcuterie, light seafood dishes, or soft cheeses like Robiola, this wine is ideal for summer aperitifs and outdoor dining. Naturally low Ingredients: dolcetto, grignolino, nebbiolo. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Rosè',
#     'menu_description': 'default preparation, a delicate blend of dolcetto grignolino and nebbiolo with the nebbiolo adding a subtle complexity offering notes of rose petal cherry and a hint of earthy undertones perfect for sipping on a warm summer evening  , vibrant italian blend showcasing dolcettos fruitforward charm complemented by grignolinos crisp acidity and nebbiolos subtle tannins a perfect rosè for sipping on a warm day',
#     'menu_item': 'idlewild flora  fauna dolcettogrignolinonebbiolo',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['dolcetto', 'grignolino', 'nebbiolo'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932133},
#    'chunk_id': 22},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Rosè',
#    'menu_description': 'default preparation, a delicate blend of dolcetto grignolino and nebbiolo with the nebbiolo adding a subtle complexity offering notes of rose petal cherry and a hint of earthy undertones perfect for sipping on a warm summer evening  , vibrant italian blend showcasing dolcettos fruitforward charm complemented by grignolinos crisp acidity and nebbiolos subtle tannins a perfect rosè for sipping on a warm day',
#    'menu_item': 'idlewild flora  fauna dolcettogrignolinonebbiolo',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['dolcetto', 'grignolino', 'nebbiolo'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932133},
#   'chunk_id': 22},
#  {'text': {'text': "kristinus siller zweigelt (Red Wine) at 20 spot. Description: A luxurious Hungarian red wine blend showcasing the rich terroir of Burgenland, this Kristinus Siller-Zweigelt offers a sophisticated sensory journey. Deep garnet in color with an intoxicating bouquet of ripe blackberries, dark cherries, and warm baking spices, the wine delivers a velvety texture and complex palate of dark fruit, subtle pepper, and smooth tannins. Ideal for pairing with robust dishes like grilled lamb, aged hard cheeses, or charcuterie boards, this medium-bodied wine is naturally gluten-free and vegan-friendly. Rooted in Austria's centuries-old winemaking Ingredients: kristinus, zweigelt, siller. Pairings: Excellent with desserts or cheese boards. Dietary: Contains alcohol. Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Red Wine',
#     'menu_description': 'smooth fullbodied siller with hints of dark fruit subtle spice and a velvety finish  , a rich fullbodied kristinus with dark fruit notes subtle spice and a smooth velvety finish  , a rich fullbodied zweigelt with dark fruit flavors subtle spice and a smooth velvety finish',
#     'menu_item': 'kristinus siller zweigelt',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['kristinus', 'zweigelt', 'siller'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932135},
#    'chunk_id': 23},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Red Wine',
#    'menu_description': 'smooth fullbodied siller with hints of dark fruit subtle spice and a velvety finish  , a rich fullbodied kristinus with dark fruit notes subtle spice and a smooth velvety finish  , a rich fullbodied zweigelt with dark fruit flavors subtle spice and a smooth velvety finish',
#    'menu_item': 'kristinus siller zweigelt',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['kristinus', 'zweigelt', 'siller'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932135},
#   'chunk_id': 23},
#  {'text': {'text': "scions of sinai atlantikas pinotage (Red Wine) at 20 spot. Description: Scions of Sinai Atlantikas Pinotage: A luxurious South African red wine expressing the rugged terroir of the Western Cape, with intense blackberry and plum notes layered with smoky tobacco and black pepper undertones. Velvety tannins and a robust structure make this wine ideal for pairing with grilled meats, aged cheeses, and hearty stews, particularly complementing robust dishes like lamb or venison. Naturally gluten-free and vegan-friendly, this medium-bodied pinotage showcases the unique heritage of South Africa's signature grape variety, originally developed in 1925 by crossing Pinot Noir and C Ingredients: pinotage, grape. Pairings: Excellent with desserts or cheese boards. Dietary: Contains alcohol. Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Red Wine',
#     'menu_description': 'a rich fullbodied pinotage with bold flavors of dark fruit subtle hints of spice and a velvety smooth finish crafted from the finest grapes  , smooth fullbodied pinotage with hints of dark fruit subtle spice and a velvety finish',
#     'menu_item': 'scions of sinai atlantikas pinotage',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['pinotage', 'grape'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932136},
#    'chunk_id': 24},
#   'metadata': {'restaurant_id': 'ee70f1d57653',
#    'restaurant_name': '20 spot',
#    'menu_category': 'Red Wine',
#    'menu_description': 'a rich fullbodied pinotage with bold flavors of dark fruit subtle hints of spice and a velvety smooth finish crafted from the finest grapes  , smooth fullbodied pinotage with hints of dark fruit subtle spice and a velvety finish',
#    'menu_item': 'scions of sinai atlantikas pinotage',
#    'price_tier': 'mid',
#    'cuisine_types': ['New American', 'Wine Bars'],
#    'ingredients': ['pinotage', 'grape'],
#    'location': 'San Francisco, CA',
#    'item_id': 24932136},
#   'chunk_id': 24},
#  {'text': {'text': 'veso solstice  soda (Vermouth) at 20 spot. Description: A crisp, herbaceous vermouth spritzer with bright botanical undertones, the Veso Solstice Soda offers a refreshing Mediterranean-inspired aperitif experience. Its delicate effervescence and complex herbal profile make it an ideal companion to light charcuterie, soft goat cheeses, and olives, perfect for pre-dinner sipping or summer afternoon gatherings. Naturally gluten-free and low-alcohol, this New American wine bar creation draws inspiration from traditional Italian and Spanish vermouth traditions, balancing delicate herbal notes with a clean, sparkling finish. Best served chilled in a tall glass with a twist of lemon or fresh herb garnish, this drink Ingredients: veso solstice  soda. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': 'ee70f1d57653',
#     'restaurant_name': '20 spot',
#     'menu_category': 'Vermouth',
#     'menu_description': 'vibrant herbaceous notes of veso solstice elevated by the crisp effervescence of soda creating a refreshing and revitalizing drink perfect for any season',
#     'menu_item': 'veso solstice  soda',
#     'price_tier': 'mid',
#     'cuisine_types': ['New American', 'Wine Bars'],
#     'ingredients': ['veso solstice  soda'],
#     'location': 'San Francisco, CA',
#     'item_id': 24932139},
#    'chunk_id': 25},
# ...
#    'metadata': {'restaurant_id': '741c3b2ed472',
#     'restaurant_name': 'blue plate',
#     'menu_category': 'Desserts',
#     'menu_description': 'vanilla ice cream candied almonds',
#     'menu_item': 'dark chocolatesea salt brownie sundae',
#     'price_tier': 'high',
#     'cuisine_types': ['American', 'Comfort Food', 'Wine Bars'],
#     'ingredients': ['sea salt',
#      'candied almonds',
#      'vanilla ice cream',
#      'dark chocolate',
#      'brownie'],
#     'location': 'San Francisco, CA',
#     'item_id': 26085139},
#    'chunk_id': 992},
#   'metadata': {'restaurant_id': '741c3b2ed472',
#    'restaurant_name': 'blue plate',
#    'menu_category': 'Desserts',
#    'menu_description': 'vanilla ice cream candied almonds',
#    'menu_item': 'dark chocolatesea salt brownie sundae',
#    'price_tier': 'high',
#    'cuisine_types': ['American', 'Comfort Food', 'Wine Bars'],
#    'ingredients': ['sea salt',
#     'candied almonds',
#     'vanilla ice cream',
#     'dark chocolate',
#     'brownie'],
#    'location': 'San Francisco, CA',
#    'item_id': 26085139},
#   'chunk_id': 992},
#  {'text': {'text': 'butterscotch pudding (Desserts) at blue plate. Description: Velvety butterscotch pudding crowned with house-made pecan brittle, offering a luxurious blend of silky-smooth custard and caramelized nutty crunch. This classic American comfort dessert features rich, golden butterscotch with deep caramel notes and a delicate buttery aroma, perfectly complemented by the toasted, crisp pecan brittle. Ideal as a decadent wine bar dessert or post-dinner indulgence, it pairs beautifully with aged tawny port or a robust bourbon. Gluten-free and vegetarian-friendly, this nostalgic treat celebrates traditional San Francisco culinary craftsmanship with its Ingredients: pecan, brittle, pudding, butterscotch. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: high. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': '741c3b2ed472',
#     'restaurant_name': 'blue plate',
#     'menu_category': 'Desserts',
#     'menu_description': 'pecan brittle',
#     'menu_item': 'butterscotch pudding',
#     'price_tier': 'high',
#     'cuisine_types': ['American', 'Comfort Food', 'Wine Bars'],
#     'ingredients': ['pecan', 'brittle', 'pudding', 'butterscotch'],
#     'location': 'San Francisco, CA',
#     'item_id': 26085141},
#    'chunk_id': 993},
#   'metadata': {'restaurant_id': '741c3b2ed472',
#    'restaurant_name': 'blue plate',
#    'menu_category': 'Desserts',
#    'menu_description': 'pecan brittle',
#    'menu_item': 'butterscotch pudding',
#    'price_tier': 'high',
#    'cuisine_types': ['American', 'Comfort Food', 'Wine Bars'],
#    'ingredients': ['pecan', 'brittle', 'pudding', 'butterscotch'],
#    'location': 'San Francisco, CA',
#    'item_id': 26085141},
#   'chunk_id': 993},
#  {'text': {'text': "chicken sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: A vibrant Vietnamese bánh mì featuring tender, marinated chicken nestled in a crisp French colonial-era baguette, layered with tangy daikon and carrot pickles, fresh cilantro, and fiery jalapeños. The sandwich delivers a harmonious balance of crunchy texture, zesty sriracha heat, and bright herbal notes, representing the culinary fusion of French and Vietnamese traditions. Perfectly paired with a cold Vietnamese iced coffee or light lager, this mid-price sandwich offers a gluten-containing, protein-rich meal ideal for lunch or casual dining. Best enjoyed fresh, it's a street food classic that captures the vibrant street food culture of Saig Ingredients: carrot pickle, chicken, jalapeño, daikon pickle, sriracha, mixed green, cilantro, french baguette. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'chicken sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['carrot pickle',
#      'chicken',
#      'jalapeño',
#      'daikon pickle',
#      'sriracha',
#      'mixed green',
#      'cilantro',
#      'french baguette'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392057},
#    'chunk_id': 994},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'chicken sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['carrot pickle',
#     'chicken',
#     'jalapeño',
#     'daikon pickle',
#     'sriracha',
#     'mixed green',
#     'cilantro',
#     'french baguette'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392057},
#   'chunk_id': 994},
#  {'text': {'text': "pork sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: A vibrant Vietnamese bánh mì featuring tender, marinated roasted pork nestled in a crisp French colonial-era baguette, layered with tangy pickled daikon and carrots, fresh cilantro, and fiery jalapeños. This street food classic delivers a harmonious balance of rich umami, bright acidity, and subtle heat, perfect for adventurous lunch-goers or as a quick, satisfying meal. Pairs beautifully with a cold Vietnamese iced coffee or a light lager, and ideal for those seeking a gluten-conscious option when ordered without the traditional wheat baguette. Rooted in Vietnam's French colonial culinary fusion, this sandwich represents Ingredients: carrot pickle, pork, jalapeño, sriracha, mixed green, daikon, cilantro, french baguette. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'pork sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['carrot pickle',
#      'pork',
#      'jalapeño',
#      'sriracha',
#      'mixed green',
#      'daikon',
#      'cilantro',
#      'french baguette'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392058},
#    'chunk_id': 995},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'pork sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['carrot pickle',
#     'pork',
#     'jalapeño',
#     'sriracha',
#     'mixed green',
#     'daikon',
#     'cilantro',
#     'french baguette'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392058},
#   'chunk_id': 995},
#  {'text': {'text': 'tofu  mushroom sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: Crisp, crusty French-style baguette cradling tender marinated tofu and umami-rich mushrooms, layered with vibrant daikon and carrot pickles that provide a tangy, crunchy counterpoint. This bánh mì balances heat from sriracha and fresh jalapeños with cooling cilantro, representing the French-Vietnamese culinary fusion born during colonial-era Indochina. Ideal for vegetarian lunch-goers seeking bold, balanced flavors, this sandwich pairs beautifully with Vietnamese iced coffee or a light, crisp lager. Naturally vegetarian and potentially vegan (depending on baguette preparation), it offers a nutritious Ingredients: carrot pickle, mushroom, jalapeño, tofu, daikon pickle, sriracha, mixed green, cilantro, french baguette. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'tofu  mushroom sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['carrot pickle',
#      'mushroom',
#      'jalapeño',
#      'tofu',
#      'daikon pickle',
#      'sriracha',
#      'mixed green',
#      'cilantro',
#      'french baguette'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392059},
#    'chunk_id': 996},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'tofu  mushroom sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['carrot pickle',
#     'mushroom',
#     'jalapeño',
#     'tofu',
#     'daikon pickle',
#     'sriracha',
#     'mixed green',
#     'cilantro',
#     'french baguette'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392059},
#   'chunk_id': 996},
#  {'text': {'text': "roasted duck sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: A crisp, crusty French-style baguette cradling succulent roasted duck, layered with vibrant daikon and carrot pickles that offer a tangy, crunchy counterpoint. The sandwich bursts with complex flavors - rich, tender duck meat complemented by spicy sriracha and fresh jalapeño, while fragrant cilantro adds bright herbaceous notes. Rooted in Vietnamese street food tradition, this bánh mì represents a delicious culinary fusion of French colonial influence and traditional Vietnamese ingredients. Perfect for a quick lunch or casual dinner, it's gluten-sensitive when served on a lettuce wrap. Pairs beautifully with a crisp Vietnamese ice Ingredients: carrot pickle, jalapeño, roasted duck, daikon pickle, sriracha, mixed greens, cilantro, french baguette. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA",
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'roasted duck sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['carrot pickle',
#      'jalapeño',
#      'roasted duck',
#      'daikon pickle',
#      'sriracha',
#      'mixed greens',
#      'cilantro',
#      'french baguette'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392060},
#    'chunk_id': 997},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'roasted duck sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['carrot pickle',
#     'jalapeño',
#     'roasted duck',
#     'daikon pickle',
#     'sriracha',
#     'mixed greens',
#     'cilantro',
#     'french baguette'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392060},
#   'chunk_id': 997},
#  {'text': {'text': 'beef sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: A classic Vietnamese bánh mì featuring tender, marinated beef nestled in a crisp French-style baguette, layered with vibrant pickled daikon and carrots that provide a tangy, crunchy counterpoint. The sandwich bursts with complex flavors - savory meat, bright herbs, and a spicy sriracha kick from fresh jalapeños, creating a harmonious street food experience rooted in French colonial culinary fusion. Ideal for a quick lunch or casual dinner, this sandwich pairs beautifully with a light Vietnamese iced coffee or a crisp lager. Perfect for those seeking a gluten-aware option when ordered on a gluten-free baguette, this bá Ingredients: pickle, beef, jalapeño, baguette, sriracha, mixed green, carrot, daikon, cilantro. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'beef sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['pickle',
#      'beef',
#      'jalapeño',
#      'baguette',
#      'sriracha',
#      'mixed green',
#      'carrot',
#      'daikon',
#      'cilantro'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392061},
#    'chunk_id': 998},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'beef sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['pickle',
#     'beef',
#     'jalapeño',
#     'baguette',
#     'sriracha',
#     'mixed green',
#     'carrot',
#     'daikon',
#     'cilantro'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392061},
#   'chunk_id': 998},
#  {'text': {'text': 'pork belly with kimchi sandwich (Vietnamese Gourmet Sandwiches (Bánh Mì)) at bobos bistro. Description: A vibrant Vietnamese bánh mì featuring succulent, crispy-edged pork belly nestled in a crusty French colonial-era baguette, layered with tangy kimchi, bright pickled daikon and carrots, and a fiery sriracha-jalapeño kick. This umami-rich sandwich balances rich, melt-in-your-mouth pork with sharp, fermented kimchi and fresh herbal cilantro, embodying the complex flavor fusion of Vietnamese street food culture. Perfect for adventurous lunch-goers seeking a bold, textural experience that bridges French and Vietnamese culinary traditions. Gluten-sensitive diners can request a lettuce wrap alternative Ingredients: pork belly, kimchi, jalapeño, sriracha, mixed greens, carrot, daikon, cilantro, french baguette. Pairings: Excellent with desserts or cheese boards. Dietary: . Price: mid. Location: San Francisco, CA',
#    'metadata': {'restaurant_id': '10a2126934bc',
#     'restaurant_name': 'bobos bistro',
#     'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#     'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#     'menu_item': 'pork belly with kimchi sandwich',
#     'price_tier': 'mid',
#     'cuisine_types': ['Vietnamese'],
#     'ingredients': ['pork belly',
#      'kimchi',
#      'jalapeño',
#      'sriracha',
#      'mixed greens',
#      'carrot',
#      'daikon',
#      'cilantro',
#      'french baguette'],
#     'location': 'San Francisco, CA',
#     'item_id': 24392062},
#    'chunk_id': 999},
#   'metadata': {'restaurant_id': '10a2126934bc',
#    'restaurant_name': 'bobos bistro',
#    'menu_category': 'Vietnamese Gourmet Sandwiches (Bánh Mì)',
#    'menu_description': 'french baguette with mixed green daikon  carrot pickle sriracha jalapeño and cilantro',
#    'menu_item': 'pork belly with kimchi sandwich',
#    'price_tier': 'mid',
#    'cuisine_types': ['Vietnamese'],
#    'ingredients': ['pork belly',
#     'kimchi',
#     'jalapeño',
#     'sriracha',
#     'mixed greens',
#     'carrot',
#     'daikon',
#     'cilantro',
#     'french baguette'],
#    'location': 'San Francisco, CA',
#    'item_id': 24392062},
#   'chunk_id': 999},
#  ...]

# %%
def create_tfidf_pipeline(chunks):
    """Create TF-IDF vectorizer and matrix using chunk texts"""
    corpus = []
    for chunk in chunks:
        text = chunk['text']
        if isinstance(text, dict) and 'text' in text:
            corpus.append(text['text'])
        else:
            corpus.append(text)
            
    vectorizer = TfidfVectorizer(
        stop_words='english',
        ngram_range=(1, 3),
        min_df=2,
        max_df=0.9,
        sublinear_tf=True
    )
    return vectorizer, vectorizer.fit_transform(corpus)

# %%
system = initialize_system(chunk_copy, enhanced_chunk_embeddings_7500_loaded)

# %%
import pickle

with open('chunks_copy.pkl', 'wb') as f:
    pickle.dump(chunks, f)

with open('vectorizer.pkl', 'wb') as f:
    pickle.dump(system["vectorizer"], f)

with open('tfidf_matrix.pkl', 'wb') as f:
    pickle.dump(system["tfidf_matrix"], f)

with open('faiss_index.pkl', 'wb') as f:
    pickle.dump(system["faiss_index"], f)

with open('faiss_index_to_chunk.pkl', 'wb') as f:
    pickle.dump(system["faiss_index_to_chunk"], f)

with open('reranker.pkl', 'wb') as f:
    pickle.dump(system["reranker"], f)

# %%
import pickle

chunks_5000 = chunk_copy[:5000]
embeddings_5000 = enhanced_chunk_embeddings_7500_loaded[:5000]


with open("chunks_5000.pkl", 'wb') as f:
    pickle.dump(chunks_5000, f)

with open("embeddings_5000.pkl", 'wb') as f:
    pickle.dump(embeddings_5000, f)


# Load each object from its respective file
with open('chunks.pkl', 'rb') as f:
    chunks = pickle.load(f)

with open('vectorizer.pkl', 'rb') as f:
    vectorizer = pickle.load(f)

with open('tfidf_matrix.pkl', 'rb') as f:
    tfidf_matrix = pickle.load(f)

with open('faiss_index.pkl', 'rb') as f:
    faiss_index = pickle.load(f)

with open('faiss_index_to_chunk.pkl', 'rb') as f:
    faiss_index_to_chunk = pickle.load(f)

with open('reranker.pkl', 'rb') as f:
    reranker = pickle.load(f)

# The objects are now loaded and available for use

# %%
with open('enhanced_chunk_embeddings_7500.pkl', 'rb') as f:
    enhanced_chunk_embeddings_7500_loaded = pickle.load(f)

# %%
import pickle

chunks_5000 = chunk_copy[:5000]
embeddings_5000 = enhanced_chunk_embeddings_7500_loaded[:5000]


with open("chunks_5000.pkl", 'wb') as f:
    pickle.dump(chunks_5000, f)

with open("embeddings_5000.pkl", 'wb') as f:
    pickle.dump(embeddings_5000, f)

# %% [markdown]
# > Used a cross encoder to re-rank the chunks against the query.

# %% [markdown]
# > With better descriptions, BM25 and semantic retreival of embeddings. The hit rate has increased by approximately 18%. We do see the new approach over performs the standard RAG.
#
# > Now we would be developing a generation end for this to complete the RAG.
