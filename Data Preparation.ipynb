# %% [markdown]
# ## About the sheet:
#
# This sheet is being used to prepare the data which would be used for creating the RAG system and then finally pushing the data to S3 bucket.

# %%
import boto3
import pandas as pd
import numpy as np
import json
import pandas as pd
import dotenv
import os

# %%
s3 = boto3.client('s3')

response = s3.list_buckets()
for bucket in response['Buckets']:
    print(f'Bucket Name: {bucket["Name"]}')
# Out:
# Bucket Name: menudatabucket

# %%
# Fetching data from S3 bucket and saving to local
bucket_name = 'menudatabucket'
file_key = 'Sample_Ingredients_File.csv' 
local_filename = 'Sample_Ingredients_File.csv'

s3.download_file(bucket_name, file_key, local_filename)
print(f"File {file_key} downloaded as {local_filename}")
# Out:
# File Sample_Ingredients_File.csv downloaded as Sample_Ingredients_File.csv

# %%
Ingredients = pd.read_csv(f"Sample_Ingredients_File.csv")
print(Ingredients.shape)
# Out:
# (52696, 16)

# %%
Ingredients["item_id"].nunique()
# Out:
# 10571

# %%
Ingredients["menu_category"].nunique()
# Out:
# 998

# %%
Ingredients["restaurant_name"].nunique()
# Out:
# 150

# %% [markdown]
# We have information on
#
# > 52696 items.
#
# > 150 restaurants.
#
# > 998 unique menu categories. Here we can see: particular day's specials(Tuesday 11-9pm), drink categories, breakfast, etc.
#
# > 10571 unique items.
#
# > Restaurants only from san francisco and 1 pincode.

# %% [markdown]
# ### Interrpretation of data:
#
# restaurant_name: Name of the restaurant.
#
# Example: '20 spot' (a restaurant in San Francisco).
# menu_category: Category of the menu item.
#
# Example: 'no proof' (likely indicating a non-alcoholic or low-alcohol drink).
# item_id: Unique identifier for the menu item.
#
# Example: 24932147 (a unique number assigned to the menu item).
# menu_item: Name of the menu item.
#
# Example: '"amaro" spritz' (a type of cocktail or drink).
# menu_description: Brief description of the menu item, often listing key ingredients.
#
# Example: 'pathfinder amaro, tonic' (describing the components of the drink).
# ingredient_name: Key ingredient(s) used in the menu item.
#
# Example: 'pathfinder amaro' (a type of non-alcoholic spirit).
# confidence: Confidence score (possibly from an ML model) indicating the certainty of ingredient classification.
#
# Example: 0.95 (95% confidence that the ingredient identification is correct).
# categories: Cuisine type(s) or restaurant classification, separated by |.
#
# Example: 'New American|Wine Bars' (restaurant serves New American cuisine and has a wine bar).
#
#
# > No proof in menu_category refers to little to no alcohol for that item.

# %%
for col in Ingredients.columns:
    print(f"{col.strip()} has null values: {Ingredients[col].isnull().sum()}")
# Out:
# restaurant_name has null values: 0
# menu_category has null values: 13
# item_id has null values: 0
# menu_item has null values: 0
# menu_description has null values: 13793
# ingredient_name has null values: 42
# confidence has null values: 0
# categories has null values: 140
# address1 has null values: 140
# city has null values: 140
# zip_code has null values: 140
# country has null values: 140
# state has null values: 140
# rating has null values: 140
# review_count has null values: 140
# price has null values: 8608

# %% [markdown]
# **Handling Missing Values:**
#
# Solution 1: We can fill out menu_description and menu_category using a large language model. We can provide context using other details.
#
# Solution 2: Another potential solution could be, integrating with some food delivery app and use their API if its accessible and then get the missing values.
#
# For now, lets work with Solution 1. I am going to be using meta llama for the same.

# %% [markdown]
# ## Setting up Bedrock

# %%
load_dotenv("Credentials")

aws_access_key_id = os.getenv("aws_access_key_id")
aws_secret_access_key = os.getenv("aws_secret_access_key")
# Out:
# 'AKIAUMYCIE27A72XFOAK'

# %%
bedrock_client = boto3.client(
    service_name = "bedrock-runtime",
    region_name="us-east-2",
    aws_access_key_id = aws_access_key_id, 
    aws_secret_access_key = aws_secret_access_key
)

# %% [markdown]
# ## Getting null values in all the columns

# %%
rows_with_null_vals = Ingredients[
    Ingredients[['menu_category', 'menu_item', 'menu_description', 'ingredient_name', 'categories']].isnull().any(axis=1)]
rows_with_null_vals["menu_description"].isnull().sum()
# Out:
# 13793

# %% [markdown]
# ### Filling out missing values in 'menu_description' columns

# %%
def generate_prompt_description(row):
    menu_category = row.get("menu_category", "")
    menu_item = row.get("menu_item", "")
    ingredient_name = row.get("ingredient_name", "")
    categories = row.get("categories", "")

    prompt = f"""You are a professional menu writer known for crafting **irresistible, mouthwatering** descriptions that captivate customers. Your task is to create a **vivid, enticing** menu description based on the given details.

### Instructions:
- **Always generate a description**—never leave it empty.
- Use the **menu item name, ingredient name, menu category, and categories** as inspiration.
- If an ingredient is provided, make it the star of the dish.
- **For food:** Use **rich, sensory phrases** to describe flavor, texture, and experience.
- **For drinks:** Keep it **short, crisp, and refreshing**, focusing on key ingredients and taste.
- **No explanations—only output the final description.**

### Examples:

#### **Drinks (Short & Crisp)**
1. **Menu Category:** No Proof  
   **Menu Item:** Pathfinder Tonic  
   **Ingredient:** Pathfinder Amaro  
   **Output:** Herbal, citrusy, and refreshingly bitter with a bright tonic finish.  

2. **Menu Category:** Cocktails  
   **Menu Item:** Smoked Old Fashioned  
   **Ingredient:** Bourbon  
   **Output:** Smooth bourbon, smoked oak, orange essence, and a hint of spice.  

3. **Menu Category:** Refreshers  
   **Menu Item:** Cucumber Cooler  
   **Ingredient:** Cucumber  
   **Output:** Crisp cucumber, fresh lime, and a cooling mint finish.  

#### **Food (Rich & Evocative)**
4. **Menu Category:** Dessert  
   **Menu Item:** Blueberry Dessert  
   **Ingredient:** Blueberry  
   **Output:** A luscious medley of plump blueberries, silky chantilly cream, and a whisper of fresh mint.  

5. **Menu Category:** Mains  
   **Menu Item:** Braised Oxtails  
   **Ingredient:** Braised Oxtails  
   **Output:** Slow-braised oxtails in a rich sungold tomato sauce, with blistered shishito peppers and fragrant herbs.  

6. **Menu Category:** Snacks  
   **Menu Item:** Marinated Olives  
   **Ingredient:** Castelvetrano Olives  
   **Output:** Buttery Castelvetrano olives kissed with citrus zest, rosemary, and a hint of chili heat.  

### Generate a description for:
- **Menu Category:** {menu_category}  
- **Menu Item:** {menu_item}  
- **Ingredient:** {ingredient_name}  
- **Categories:** {categories}  

**Output only the final description. No explanations or extra text.**"""

    return prompt




# Temperature can be kept higher here, creativity would be good for this task
def get_description_from_bedrock(prompt):
    model_id = "meta.llama3-3-70b-instruct-v1:0"
    payload = {
        "prompt": prompt,
        "temperature": 0.7
    }
    
    try:
        response = bedrock_client.invoke_model(
            modelId=model_id,
            body=json.dumps(payload),
            contentType="application/json",
            accept="application/json"
        )
        result = json.loads(response["body"].read().decode("utf-8"))
        description = result.get("generation", "").strip()
        
        description = description.split('\n')[0]
        description = description.rstrip('.') 
        description = description.lower() 
        
        return description
    except Exception as e:
        print(f"Error invoking model: {e}")
        return "default preparation"  

desc_cnt = 0


for index, row in rows_with_null_vals.iterrows():
    if pd.isnull(row["menu_description"]) and desc_cnt <=50:
        menu_category = row.get("menu_category", "")
        menu_item = row.get("menu_item", "")
        ingredient_name = row.get("ingredient_name", "")
        categories = row.get("categories", "")

        print(f"  Category: {menu_category}")
        print(f"  Item: {menu_item}")
        print(f"  Ingredient: {ingredient_name}")
        print(f"  Categories: {categories}")

        prompt = generate_prompt_description(row)
        generated_description = get_description_from_bedrock(prompt)

        rows_with_null_vals.at[index, "menu_description"] = generated_description
        print(f"  Generated Description: {generated_description}\n")
        desc_cnt+=1
        print(desc_cnt, "done")
        print()
# Out:
#   Category: pet-nat & sparkling wine
#   Item: athenais de beru, ‘love joy’, chardonnay
#   Ingredient: athenais de beru, 'love joy', chardonnay
#   Categories: New American|Wine Bars
#   Generated Description: fresh, lively, and effervescent, with notes of green apple, citrus zest, and a hint of floral sweetness.
#
# 1 done
#
#   Category: pet-nat & sparkling wine
#   Item: broc cellars, valdigué
#   Ingredient: nan
#   Categories: New American|Wine Bars
#   Generated Description: sparkling valdigué with a lively, fruity nose and a crisp, refreshing finish.
#
# 2 done
#
#   Category: pet-nat & sparkling wine
#   Item: cantina marilina, 'fedelie', moscato
#   Ingredient: moscato
#   Categories: New American|Wine Bars
#   Generated Description: petite bubbles dance on the palate, as moscato's floral sweetness and crisp citrus notes unfold in this lively, sun-kissed italian sparkler.
#
# 3 done
#
#   Category: pet-nat & sparkling wine
#   Item: casa coste piane, 'brichet', glera/verdiso
#   Ingredient: glera
#   Categories: New American|Wine Bars
#   Generated Description: vibrant glera shines in this pet-nat, bursting with green apple, citrus, and a delicate floral hint, finishing crisp and refreshing.
#
# 4 done
#
#   Category: pet-nat & sparkling wine
#   Item: casa coste piane, 'brichet', glera/verdiso
#   Ingredient: verdiso
#   Categories: New American|Wine Bars
#   Generated Description: fresh, crisp verdiso notes dance on the palate, complemented by hints of green apple and a delicate, effervescent finish.
#
# 5 done
#
#   Category: beer
#   Item: dust bowl brewing, hazy ipa
#   Ingredient: barley
#   Categories: New American|Wine Bars
#   Generated Description: smooth, hazy ipa with a rich barley backbone, bursting with juicy citrus and tropical fruit notes, and a hint of earthy undertones.
#
# 6 done
#
#   Category: beer
#   Item: dust bowl brewing, hazy ipa
#   Ingredient: dust bowl brewing, hazy ipa
#   Categories: New American|Wine Bars
#   Generated Description: smooth, full-bodied hazy ipa from dust bowl brewing, bursting with juicy citrus flavors, a hint of tropical fruit, and a soft, velvety finish.
#
# 7 done
#
#   Category: beer
#   Item: dust bowl brewing, hazy ipa
#   Ingredient: hops
#   Categories: New American|Wine Bars
#   Generated Description: a hazy ipa bursting with tropical fruit flavors, dank earthy notes, and a crisp, refreshing finish, showcasing the bold, citrusy essence of hops.
#
# 8 done
#
#   Category: beer
#   Item: dust bowl brewing, hazy ipa
#   Ingredient: yeast
#   Categories: New American|Wine Bars
#   Generated Description: a hazy, full-bodied ipa with a velvety texture, bursting with juicy tropical fruit flavors and a hint of earthy yeast undertones, finishing crisp and refreshing.
#
# 9 done
#
#   Category: beer
#   Item: faction, pale ale
#   Ingredient: faction, pale ale
#   Categories: New American|Wine Bars
#   Generated Description: a crisp, hoppy pale ale with a hint of citrus and a refreshing finish.
#
# 10 done
#
#   Category: rosè
#   Item: idlewild, flora & fauna, dolcetto/grignolino/nebbiolo
#   Ingredient: dolcetto
#   Categories: New American|Wine Bars
#   Generated Description: vibrant italian blend, showcasing dolcetto's fruit-forward charm, complemented by grignolino's crisp acidity and nebbiolo's subtle tannins, a perfect rosè for sipping on a warm day.
#
# 11 done
#
#   Category: rosè
#   Item: idlewild, flora & fauna, dolcetto/grignolino/nebbiolo
#   Ingredient: grignolino
#   Categories: New American|Wine Bars
# Error invoking model: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many tokens, please wait before trying again.
#   Generated Description: default preparation
#
# 12 done
#
#   Category: rosè
#   Item: idlewild, flora & fauna, dolcetto/grignolino/nebbiolo
#   Ingredient: nebbiolo
#   Categories: New American|Wine Bars
#   Generated Description: a delicate blend of dolcetto, grignolino, and nebbiolo, with the nebbiolo adding a subtle complexity, offering notes of rose petal, cherry, and a hint of earthy undertones, perfect for sipping on a warm summer evening.
#
# 13 done
#
#   Category: red wine
#   Item: kristinus, 'siller', zweigelt
#   Ingredient: kristinus
#   Categories: New American|Wine Bars
#   Generated Description: a rich, full-bodied kristinus with dark fruit notes, subtle spice, and a smooth, velvety finish.
#
# 14 done
#
#   Category: red wine
#   Item: kristinus, 'siller', zweigelt
#   Ingredient: siller
#   Categories: New American|Wine Bars
#   Generated Description: smooth, full-bodied siller with hints of dark fruit, subtle spice, and a velvety finish.
#
# 15 done
#
#   Category: red wine
#   Item: kristinus, 'siller', zweigelt
#   Ingredient: zweigelt
#   Categories: New American|Wine Bars
#   Generated Description: a rich, full-bodied zweigelt with dark fruit flavors, subtle spice, and a smooth, velvety finish.
#
# 16 done
#
#   Category: champagne
#   Item: marguet, ‘shaman’, grand cru
#   Ingredient: champagne
#   Categories: New American|Wine Bars
#   Generated Description: elegant, refined champagne with hints of toasted brioche, apple, and a delicate floral finish.
#
# 17 done
#
#   Category: champagne
#   Item: marguet, ‘shaman’, grand cru
#   Ingredient: grapes
#   Categories: New American|Wine Bars
#   Generated Description: delicate, crisp champagne crafted from the finest grapes, offering a rich, velvety texture and a subtle hint of oak, finished with a refreshing, fruity bouquet.
#
# 18 done
#
#   Category: sparkling
#   Item: paladin, sparkilng red, raboso fiore
#   Ingredient: raboso fiore
#   Categories: New American|Wine Bars
#   Generated Description: a glass of paladin, sparkling red, raboso fiore, bursting with juicy cherry and plum flavors, hints of rose petal, and a crisp, refreshing finish.
#
# 19 done
#
#   Category: dessert wine
#   Item: passagem porto
#   Ingredient: port
#   Categories: New American|Wine Bars
#   Generated Description: rich, velvety port, with hints of dark chocolate, caramel, and a subtle nutty undertone, perfect for sipping on its own or pairing with decadent desserts.
#
# 20 done
#
#   Category: dessert wine
#   Item: patricius, aszu 5, tokaj
#   Ingredient: tokaji aszú
#   Categories: New American|Wine Bars
#   Generated Description: sweet, honeyed tokaji aszú, with notes of dried apricot, orange blossom, and a hint of spice, offering a luscious and velvety finish.
#
# 21 done
#
#   Category: sparkling
#   Item: paul dethune, ‘ambonnay’, grand cru brut champagne
#   Ingredient: paul dethune, 'ambonnay', grand cru brut champagne
#   Categories: New American|Wine Bars
#   Generated Description: fine, elegant bubbles dance on the palate, with notes of toasted brioche, apple, and a hint of citrus, finishing with a crisp, refreshing minerality.
#
# 22 done
#
#   Category: champagne
#   Item: paul déthune, premier cru rosé
#   Ingredient: paul déthune, premier cru rosé
#   Categories: New American|Wine Bars
#   Generated Description: crisp and elegant, with a delicate balance of strawberry, rose petal, and subtle hints of toasted brioche, finishing with a refined and refreshing effervescence.
#
# 23 done
#
#   Category: no proof
#   Item: ration ale, citrus hazy ipa na
#   Ingredient: ration ale, citrus hazy ipa na
#   Categories: New American|Wine Bars
#   Generated Description: fresh, citrusy, and hoppy with a crisp, refreshing finish.
#
# 24 done
#
#   Category: red wine
#   Item: scions of sinai, 'atlantikas', pinotage
#   Ingredient: grape
#   Categories: New American|Wine Bars
#   Generated Description: a rich, full-bodied pinotage with bold flavors of dark fruit, subtle hints of spice, and a velvety smooth finish, crafted from the finest grapes.
#
# 25 done
#
#   Category: red wine
#   Item: scions of sinai, 'atlantikas', pinotage
#   Ingredient: pinotage
#   Categories: New American|Wine Bars
#   Generated Description: smooth, full-bodied pinotage with hints of dark fruit, subtle spice, and a velvety finish.
#
# 26 done
#
#   Category: white
#   Item: sziegl pince, "jonas" olaszrizling blend
#   Ingredient: olaszrizling
#   Categories: New American|Wine Bars
#   Generated Description: a crisp and refreshing blend of olaszrizling, with hints of green apple, citrus, and a subtle minerality, perfect for pairing with our seasonal small plates.
#
# 27 done
#
#   Category: pet-nat & sparkling wine
#   Item: van hunks, cap classique brut
#   Ingredient: van hunks, cap classique brut
#   Categories: New American|Wine Bars
#   Generated Description: fine bubbles dance in this elegant cap classique brut, with hints of green apple, toasted brioche, and a crisp, refreshing finish.
#
# 28 done
#
#   Category: vermouth
#   Item: veso nightfall on the rocks
#   Ingredient: vermouth
#   Categories: New American|Wine Bars
#   Generated Description: vermouth's subtle complexity shines in veso nightfall, served on the rocks with a twist of citrus, offering a crisp, herbaceous taste with hints of botanicals and a smooth, refreshing finish.
#
# 29 done
#
#   Category: vermouth
#   Item: veso nightfall on the rocks
#   Ingredient: veso nightfall on the rocks
#   Categories: New American|Wine Bars
#   Generated Description: veso nightfall on the rocks, a rich, velvety blend of dark fruit and spices, served chilled and smooth, perfect for a sophisticated evening.
#
# 30 done
#
#   Category: vermouth
#   Item: veso solstice & soda
#   Ingredient: veso solstice & soda
#   Categories: New American|Wine Bars
#   Generated Description: vibrant, herbaceous notes of veso solstice, elevated by the crisp effervescence of soda, creating a refreshing and revitalizing drink perfect for any season.
#
# 31 done
#
#   Category: white
#   Item: vorspannhof mayr, grüner veltliner
#   Ingredient: grüner veltliner
#   Categories: New American|Wine Bars
#   Generated Description: a crisp glass of grüner veltliner, bursting with green apple, white pepper, and a hint of minerality.
#
# 32 done
#
#   Category: pet-nat & sparkling wine
#   Item: woods wine, ‘feliz creek’, pet-nat carignan
#   Ingredient: feliz creek
#   Categories: New American|Wine Bars
#   Generated Description: sparkling with life, the 'feliz creek' pet-nat carignan from woods wine is a vibrant dance of cherry, wild strawberry, and a hint of earthy undertones, all wrapped in a lively, effervescent embrace.
#
# 33 done
#
#   Category: pet-nat & sparkling wine
#   Item: woods wine, ‘feliz creek’, pet-nat carignan
#   Ingredient: pet-nat carignan
#   Categories: New American|Wine Bars
#   Generated Description: vibrant, pet-nat carignan with hints of wild berries, earthy undertones, and a lively effervescence.
#
# 34 done
#
#   Category: pet-nat & sparkling wine
#   Item: woods wine, ‘feliz creek’, pet-nat carignan
#   Ingredient: woods wine
#   Categories: New American|Wine Bars
#   Generated Description: vibrant, fruity notes of woods wine, ‘feliz creek’, pet-nat carignan, bursting with citrus and a hint of earthy undertones, finished with a lively, effervescent sparkle.
#
# 35 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: buttermilk
#   Categories: New American
#   Generated Description: indulge in the harmonious fusion of hamachi & crab tartare, elevated by the creamy richness of namasu yuzu buttermilk, the subtle zest of thai basil, and the luscious sweetness of k & j cherries, all blending in perfect symphony.
#
# 36 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: cherries
#   Categories: New American
# Error invoking model: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many tokens, please wait before trying again.
#   Generated Description: default preparation
#
# 37 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: crab
#   Categories: New American
#   Generated Description: indulge in the harmonious union of succulent hamachi and luscious crab, expertly blended with the zesty zing of namasu yuzu buttermilk, the aromatic essence of thai basil, and the sweet pop of k & j cherries, all coming together in a refreshing, oceanic symphony that will leave you craving more.
#
# 38 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: hamachi
#   Categories: New American
#   Generated Description: indulge in the ocean's freshness with our hamachi & crab tartare, delicately mixed with the zesty zing of namasu yuzu buttermilk, the subtle warmth of thai basil, and the luscious sweetness of k & j cherries, all harmonizing to elevate the buttery richness of the hamachi.
#
# 39 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: thai basil
#   Categories: New American
#   Generated Description: indulge in the harmonious fusion of hamachi & crab tartare, elevated by the zesty essence of namasu yuzu buttermilk, the subtle nuance of thai basil, and the luscious sweetness of k & j cherries, all blending in perfect symphony to delight your senses.
#
# 40 done
#
#   Category: chefs tasting
#   Item: *hamachi & crab tartare, namasu yuzu buttermilk, thai basil, k & j cherries
#   Ingredient: yuzu
#   Categories: New American
#   Generated Description: tender hamachi and sweet crab, elevated by the zesty zing of yuzu, the creaminess of buttermilk, and the subtle warmth of thai basil, finished with the pop of juicy cherries
#
# 41 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: blueberry
#   Categories: New American
# Error invoking model: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many tokens, please wait before trying again.
#   Generated Description: default preparation
#
# 42 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: hojicha
#   Categories: New American
#   Generated Description: hojicha panna cotta, a creamy canvas infused with the subtle, roasted essence of hojicha, is elevated by a vibrant tapestry of flavors and textures: the tartness of rhubarb and blueberry, the exotic sweetness of passion fruit, and the satisfying crunch of pine nut granola, all harmonizing in a symphony of new american innovation.
#
# 43 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: panna cotta
#   Categories: New American
#   Generated Description: a symphony of creamy hojicha panna cotta, tart rhubarb and blueberry, vibrant passion fruit, and crunchy pine nut granola, harmoniously blending new american innovation with traditional flavors.
#
# 44 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: passion fruit
#   Categories: New American
#   Generated Description: indulge in a symphony of textures and flavors with our chefs tasting, featuring a delicate hojicha panna cotta, a vibrant rhubarb and blueberry compote, the tropical sweetness of passion fruit, and the satisfying crunch of pine nut granola, all harmoniously blended to delight your senses.
#
# 45 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: pine nut granola
#   Categories: New American
#   Generated Description: indulge in a symphony of textures and flavors with our chefs tasting, featuring a delicate hojicha panna cotta, a vibrant medley of rhubarb and blueberry, the tropical essence of passion fruit, all harmoniously topped with a crunchy, nutty pine nut granola, blending the warmth of new american cuisine with the simplicity of nature's sweetness.
#
# 46 done
#
#   Category: chefs tasting
#   Item: *hojicha panna cotta, rhubarb & blueberry, passion fruit, pine nut granola
#   Ingredient: rhubarb
#   Categories: New American
#   Generated Description: savor the harmony of sweet and tart, as tender rhubarb mingles with creamy hojicha panna cotta, a pop of juicy blueberry, and the vibrant zest of passion fruit, all atop a crunchy bed of pine nut granola, blending earthy and fruity notes in a new american symphony.
#
# 47 done
#
#   Category: chefs tasting
#   Item: *maine diver scallop, rock shrimp wild rice, fiddlehead, lobster nage
#   Ingredient: fiddlehead
#   Categories: New American
#   Generated Description: indulge in the tender sweetness of maine diver scallops, succulent rock shrimp, and the earthy charm of fiddlehead, all harmoniously balanced with the nutty depth of wild rice and enveloped in a rich, velvety lobster nage.
#
# 48 done
#
#   Category: chefs tasting
#   Item: *maine diver scallop, rock shrimp wild rice, fiddlehead, lobster nage
#   Ingredient: lobster
#   Categories: New American
#   Generated Description: indulge in the opulence of our chef's tasting, featuring succulent maine diver scallops, rock shrimp, and wild rice, all harmoniously paired with the tender crunch of fiddlehead and enveloped in a rich, velvety lobster nage that embodies the essence of new american cuisine.
#
# 49 done
#
#   Category: chefs tasting
#   Item: *maine diver scallop, rock shrimp wild rice, fiddlehead, lobster nage
#   Ingredient: maine diver scallop
#   Categories: New American
#   Generated Description: indulge in the succulent maine diver scallop, seared to perfection and served atop a bed of nutty wild rice, alongside tender rock shrimp, delicate fiddlehead ferns, and enveloped in a rich, velvety lobster nage that harmoniously unites the ocean's bounty with the earthy undertones of the forest, a quintessential new american culinary experience.
#
# 50 done
#
#   Category: chefs tasting
#   Item: *maine diver scallop, rock shrimp wild rice, fiddlehead, lobster nage
#   Ingredient: nage
#   Categories: New American
#   Generated Description: indulge in the succulent maine diver scallop, perfectly seared and served atop a bed of nutty wild rice, tender fiddlehead ferns, and succulent rock shrimp, all harmoniously bathed in a rich, velvety lobster nage that elevates each component with its deep, buttery flavor.
#
# 51 done

# %%
rows_with_null_vals["menu_description"].isnull().sum()
# Out:
# 13742

# %% [markdown]
# ## Filling Category Information

# %% [markdown]
# > On the basis of all categories, on a high level I can club them into these categories.
# >
# >  This is done so as to reduce the prompt length where we would have to pass a huge prompt. As we have almost 1000 categories.

# %%
# Allowed categories for strict matching
allowed_categories = {
    "Meals & Main Courses",
    "Breakfast & Brunch",
    "Appetizers & Sides",
    "Beverages",
    "Desserts & Sweets",
    "Specialty Menus & Offers",
    "Alcoholic Beverages & Wines",
    "International/Regional Dishes",
    "Healthy & Dietary Specific",
    "Seasonal & Limited Offerings",
    "Specialty Drinks",
    "Kids & Family Menus",
    "Snacks & Quick Bites",
    "Fresh & Organic Options",
    "Meals with Alcohol Pairings",
    "Unknown",
}

def generate_prompt_category(row):
    """Generate a prompt for categorization based on menu details."""
    menu_item = row.get("menu_item", "")
    menu_description = row.get("menu_description", "")
    ingredient_name = row.get("ingredient_name", "")

    prompt = f"""You are a food categorization system. Output ONLY the category name, no explanations, no additional text.

### RULES:
1. Output ONLY the category name.
2. NO explanations or extra text.
3. NO punctuation.
4. Choose from these categories ONLY:
{', '.join(allowed_categories)}

### Examples:

#### Correct Outputs:
- **Input:** Pancakes, fluffy with maple syrup  
  **Output:** Breakfast & Brunch  

- **Input:** Spaghetti Carbonara, creamy sauce with pancetta  
  **Output:** Meals & Main Courses  

- **Input:** Chocolate Lava Cake, rich molten chocolate center  
  **Output:** Desserts & Sweets  

- **Input:** Unknown dish with no clear category  
  **Output:** Unknown  

### Categorize this item:
- **Menu Item:** {menu_item}  
- **Menu Description:** {menu_description}  
- **Main Ingredient:** {ingredient_name}  

**Output only the category name.**"""

    return prompt

def get_category_from_bedrock(prompt):
    """Invoke the Bedrock model and retrieve the category."""
    model_id = "meta.llama3-3-70b-instruct-v1:0"
    payload = {
        "prompt": prompt,
        "temperature": 0.2  # Low temperature for consistency
    }
    
    try:
        response = bedrock_client.invoke_model(
            modelId=model_id,
            body=json.dumps(payload),
            contentType="application/json",
            accept="application/json"
        )
        result = json.loads(response["body"].read().decode("utf-8"))
        
        # Ensure category is correctly extracted
        category = result.get("generation", "").strip().split("\n")[0].strip().rstrip('.')

        # Return category only if valid, otherwise default to "Unknown"
        return category if category in allowed_categories else "Unknown"
        
    except Exception as e:
        print(f"Error invoking model: {e}")
        return "Unknown"

for index, row in rows_with_null_vals.iterrows():
    if pd.isnull(row["menu_category"]):
        
        menu_category = row.get("menu_category", "")
        menu_item = row.get("menu_item", "")
        ingredient_name = row.get("ingredient_name", "")
        categories = row.get("categories", "")

        print(f"Category: {menu_category}")
        print(f"Item: {menu_item}")
        print(f"Ingredient: {ingredient_name}")
        print(f"Categories: {categories}")

        prompt = generate_prompt_category(row)
        predicted_category = get_category_from_bedrock(prompt)
        rows_with_null_vals.at[index, "menu_category"] = predicted_category
        print(f"Predicted Category: {predicted_category}")
        print()
# Out:
# Category: nan
# Item: ceviche tostadas
# Ingredient: chicken
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: International/Regional Dishes
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: flounder
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Appetizers & Sides
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: fried flounder
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Appetizers & Sides
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: lemon juice
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Appetizers & Sides
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: onions
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Appetizers & Sides
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: peppers
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Appetizers & Sides
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: salmon
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: International/Regional Dishes
#
# Category: nan
# Item: ceviche tostadas
# Ingredient: tostada shells
# Categories: Burgers|Breakfast & Brunch|New American
# Predicted Category: Meals & Main Courses
#
# Category: nan
# Item: balea
# Ingredient: txakoli
# Categories: American|Cocktail Bars|Breakfast & Brunch
# Predicted Category: Alcoholic Beverages & Wines
#
# Category: nan
# Item: pratsch
# Ingredient: rose
# Categories: American|Cocktail Bars|Breakfast & Brunch
# Predicted Category: Alcoholic Beverages & Wines
#
# Category: nan
# Item: terra forte rouge
# Ingredient: grenache
# Categories: American|Cocktail Bars|Breakfast & Brunch
# Predicted Category: Alcoholic Beverages & Wines
#
# Category: nan
# Item: terra forte rouge
# Ingredient: red wine
# Categories: American|Cocktail Bars|Breakfast & Brunch
# Predicted Category: Alcoholic Beverages & Wines
#
# Category: nan
# Item: plum wine (4oz)
# Ingredient: plum wine
# Categories: Asian Fusion
# Predicted Category: Alcoholic Beverages & Wines

# %%
rows_with_null_vals["menu_category"].isnull().sum()
# Out:
# 0

# %%
import re
import json
import pandas as pd

def generate_ingredient_prompt(row):
    """Generate a refined prompt for the LLM, passing the extracted ingredient for validation."""
    menu_item = row.get("menu_item", "")
    menu_description = row.get("menu_description", "")
    menu_category = row.get("menu_category", "")
    categories = row.get("categories", "")
    
    prompt = f"""You are a very intelligent AI assistant that extracts key ingredients from food items. 
Your task is to see the menu_category, menu_item, and categories, accordingly give the key ingredients for this food item.
### Examples:
#### Input:  
**Menu Category:** Pizza  
**Menu Item:** Margherita Pizza  
**Menu Description:** Fresh basil, tomato sauce, mozzarella  
**Extracted Ingredient:** basil, tomato, sauce  
**Categories:** Italian, Vegetarian  
#### Output:  
mozzarella, basil, tomato  

#### Input:  
**Menu Category:** Sandwiches  
**Menu Item:** BBQ Pulled Pork  
**Menu Description:** Slow-cooked pork in smoky BBQ sauce  
**Extracted Ingredient:** pork, smoky, BBQ  
**Categories:** American, Meat  
#### Corrected Output:  
pulled pork, BBQ sauce  

---
### Your task:  
Given the following Menu Item, Menu Description, Menu Category and categories, give a list that contains only the key ingredients for this food item.  
- **Menu Item:** {menu_item}  
- **Menu Description:** {menu_description}  
- **Menu Category:** {menu_category}  
- **Categories:** {categories} 

**Output Instructions**
- Give only the ingredient list, separated by commas.
- Limit to **4-5 key ingredients**.  
- No explanations, extra words, or formatting—just the list.

**Output only the ingredients.**

"""
    return prompt


def clean_output(ingredient_str):
    """Clean the output to ensure only 4-5 ingredients are included."""
    # Split the ingredients by commas
    ingredients = ingredient_str.split(",")
    
    # Limit to the first 4 ingredients using regex and strip extra spaces
    ingredients = [ingredient.strip() for ingredient in ingredients[:4]]
    
    # Join the ingredients back together with commas
    return ", ".join(ingredients)


def get_ingredient_from_bedrock(prompt):
    """Invoke the Bedrock model to get an ingredient name."""
    model_id = "meta.llama3-3-70b-instruct-v1:0"
    payload = {
        "prompt": prompt,
        "temperature": 0.5
    }
    
    try:
        response = bedrock_client.invoke_model(
            modelId=model_id,
            body=json.dumps(payload),
            contentType="application/json",
            accept="application/json"
        )
        result = json.loads(response["body"].read().decode("utf-8"))
        
        ingredient = result.get("generation", "").strip().split("\n")[0].strip().rstrip('.')
        return clean_output(ingredient) if ingredient else "Unknown"
        
    except Exception as e:
        print(f"Error invoking model: {e}")
        return "Unknown"

cnt = 0
for index, row in rows_with_null_vals.iterrows():
    if pd.isnull(row["ingredient_name"]) and cnt <=50:
        
        # Generate refined LLM prompt and get cleaned ingredients
        prompt = generate_ingredient_prompt(row)
        final_ingredient = get_ingredient_from_bedrock(prompt)
        menu_category = row.get("menu_category", "")
        menu_item = row.get("menu_item", "")
        categories = row.get("categories", "")
        print(f"Category: {menu_category}")
        print(f"Item: {menu_item}")
        print(f"Categories: {categories}")
        print(f"Predicted ingredients: {final_ingredient}")
        rows_with_null_vals.at[index, "ingredient_name"] = final_ingredient  
        cnt += 1
        print(cnt, "done\n")
# Out:
# Category: pet-nat & sparkling wine
# Item: broc cellars, valdigué
# Categories: New American|Wine Bars
# Predicted ingredients: valdigué, grapes, yeast, sugar
# 1 done
#
# Category: sweet dessert wines
# Item: loupiac, chateau dauphine rondeillon, 2009
# Categories: New American
# Predicted ingredients: grapes, sugar, yeast, water
# 2 done
#
# Category: dessert - fortified wines
# Item: ruby port, lbv, faria vinhos, 2015
# Categories: New American
# Predicted ingredients: ruby, port, grapes, wine
# 3 done
#
# Category: dessert - fortified wines
# Item: tawny port, taylor fladgate, 2017
# Categories: New American
# Predicted ingredients: tawny port, grapes, wine, taylor fladgate
# 4 done
#
# Category: pu-erh
# Item: 1998 ripe shu pu-erh tea cake
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea leaves, tea, pu-erh, tea cake
# 5 done
#
# Category: pu-erh
# Item: 2013 ripe pu-erh tea and jiaogulan
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea, jiaogulan  tea leaves, water  tea, jiaogulan
# 6 done
#
# Category: pu-erh
# Item: 2013 ripe pu-erh tea and sticky rice herb
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea, sticky rice, herbs  tea leaves, rice  pu-erh
# 7 done
#
# Category: pu-erh
# Item: 2014 “wui liang mountain” wild arbor raw pu-erh tea cake
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea leaves, wild arbor tea, tea cake, raw pu-erh
# 8 done
#
# Category: pu-erh
# Item: 2014 menghai te ji grade loose leaf ripe pu-erh tea
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea leaves, tea, pu-erh, leaves
# 9 done
#
# Category: pu-erh
# Item: 2014 yiwu dasan ming feng chaoyang ripe dc shu-puerh
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: puerh tea, nan tea leaves, yiwu tea, chaoyang tea
# 10 done
#
# Category: pu-erh
# Item: 2016 “huang shan gu shu” old arbor raw pu-erh tea cake
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea leaves, tea, old arbor, raw pu-erh
# 11 done
#
# Category: pu-erh
# Item: 2016 “wa long village” yi wu old arbor raw pu-erh tea cake
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: tea leaves, pu-erh tea, arbor tree leaves, yunnan tea
# 12 done
#
# Category: pu-erh
# Item: 2016 menghai lao cha tou ripe shu pu-erh tea brick
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea leaves, tea brick, pu-erh tea, tea
# 13 done
#
# Category: white
# Item: 2017 early spring sun dried buds wild pu-erh tea varietal
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: pu-erh tea, buds, sun dried tea leaves, wild tea
# 14 done
#
# Category: matcha & gyokuro
# Item: 2017 kirishima-shi kagoshima, japan superior grade macha from shutaro
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: macha, green tea, matcha powder, japan tea leaves
# 15 done
#
# Category: matcha & gyokuro
# Item: 2017 kirishima-shi, kagoshima, japan superior grade macha from shutaro
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: matcha, green tea, japan tea, macha
# 16 done
#
# Category: matcha & gyokuro
# Item: 2017 tokushima, japan, rare post fermented and pickled wild second flush tea leaves
# Categories: Coffee & Tea|Juice Bars & Smoothies|Vegan
# Predicted ingredients: wild tea leaves, matcha, gyokuro, green tea  leaves
# 17 done
#
# Category: main features
# Item: grilled 21-day aged wagyu new york, served with the above accompaniments
# Categories: Breakfast & Brunch|Mediterranean|Cocktail Bars
# Predicted ingredients: wagyu beef, new york steak, accompaniments,
# 18 done
#
# Category: wine by the glass
# Item: 0% no booze
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: raspberry, chamomile, sparkling wine, salt
# 19 done
#
# Category: sonoma, mendocino & santa cruz mountains
# Item: 1986 chardonnay, hanzell
# Categories: New American|French|Wine Bars
# Predicted ingredients: chardonnay, wine, grapes, oak
# 20 done
#
# Category: luigi ferrando, ivrea
# Item: 2007 carema ‘etichetta nera
# Categories: New American|French|Wine Bars
# Predicted ingredients: No ingredients can be extracted from the given information
# 21 done
#
# Category: savoie
# Item: 2012 arbin ‘la rouge,’ magnin
# Categories: New American|French|Wine Bars
# Predicted ingredients: arbin, magnin, rouge, savoie
# 22 done
#
# Category: trentino & valtellina
# Item: 2013 ‘granato,’ foradori
# Categories: New American|French|Wine Bars
# Predicted ingredients: No ingredients available.  No output.  Empty list., , ,
# 23 done
#
# Category: savoie
# Item: 2016 mondeuse ‘saint jean de la porte,’ chevillard
# Categories: New American|French|Wine Bars
# Predicted ingredients: mondeuse, chevillard, saint jean de la porte, savoie
# 24 done
#
# Category: bebidas
# Item: 16 oz bottle water
# Categories: Mexican
# Predicted ingredients: water
# 25 done
#
# Category: antipasti & specialities
# Item: two cheese plate dinner
# Categories: Wine Bars|Cafes|Brazilian
# Predicted ingredients: gorgonzola, manchego, cheese, accompaniments  -> no
# 26 done
#
# Category: additional services - bay area delivery fees
# Item: 50+ miles from sf (based on mileage)
# Categories: Vietnamese|Noodles|Caterers
# Predicted ingredients: (There are no ingredients for this item)  No ingredients are listed for this item. There are no ingredients for this item. No ingredients. No ingredients are listed for this item. No ingredients
# 27 done
#
# Category: common
# Item: bag
# Categories: Asian Fusion|Indonesian
# Predicted ingredients: None, unknown, no ingredients listed.  No ingredients can be extracted from the given information
# 28 done
#
# Category: side items & a la carte
# Item: a la carte
# Categories: Mexican|Filipino|Asian Fusion
# Predicted ingredients: Since there is no description, I will provide a general list of ingredients that are commonly found in a la carte items in Mexican, Filipino, and Asian Fusion cuisine
# 29 done
#
# Category: burgers & sandwiches
# Item: additional toppings for any sandwich
# Categories: Bars|Breakfast & Brunch|American
# Predicted ingredients: cheddar, bacon, mushroom, avocado
# 30 done
#
# Category: BURGERS & SANDWICHES
# Item: additional toppings for any sandwich
# Categories: Bars|Breakfast & Brunch|American
# Predicted ingredients: cheddar, bacon, mushroom, avocado
# 31 done
#
# Category: madeira selections - 2oz. pours
# Item: 1885 blandy’s . verdelho
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: verdelho, brandy, grapes, sugar
# 32 done
#
# Category: madeira selections - 2oz. pours
# Item: 1895 araujo . malvasia
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: malvasia, araujo, madeira, wine
# 33 done
#
# Category: madeira selections - 2oz. pours
# Item: 1899 d’oliveira . terrantez
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: madeira wine, terrantez grape, sugar, acidity regulators
# 34 done
#
# Category: madeira selections - 2oz. pours
# Item: 1901 d’oliveira . malvasia
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: malvasia, madeira, grapes, wine
# 35 done
#
# Category: madeira selections - 2oz. pours
# Item: 1928 d’oliveira . sercial
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: None, Madeira wine, sercial grapes, sugar
# 36 done
#
# Category: madeira selections - 2oz. pours
# Item: 1932 d’oliveira . verdelho
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: verdelho, madeira, grapes, wine
# 37 done
#
# Category: madeira selections - 2oz. pours
# Item: 1982 d’oliveira . boal
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: madeira wine, boal grapes, sugar, alcohol
# 38 done
#
# Category: ciders and co-ferments
# Item: 2021 phelan farm . ‘bottle baby’ . cambria
# Categories: New American|Cocktail Bars|Desserts
# Predicted ingredients: apples, cambria grapes, yeast, sugar
# 39 done
#
# Error invoking model: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Category: spirits menu - madeira/port/macvin, etc.
# Item: berthet bondet 1986 macvin du jura, chateau chalon, jura, france, 18%
# Categories: Cocktail Bars|Breakfast & Brunch|American
# Predicted ingredients: Unknown
# 40 done
#
# Category: beverages
# Item: 240. bottled water
# Categories: Chinese
# Predicted ingredients: water
# 41 done
#
# Category: beverages
# Item: 241. gatorade
# Categories: Chinese
# Predicted ingredients: water, sugar, flavorings, citric acid
# 42 done

# %%
rows_with_null_vals.to_csv("rows_with_null_vals.csv")

# %%
rows_with_null_vals = pd.read_csv("rows_with_null_vals.csv").drop(["Unnamed: 0"], axis = 1)

# %% [markdown]
# > For demo purpose, we have filled the data here. Similar approach can be taken to fill categories also.

# %%
Ingredients
# Out:
#       restaurant_name             menu_category   item_id  \
# 0             20 spot                  no proof  24932147
# 1             20 spot                  no proof  24932146
# 2             20 spot                  no proof  24932145
# 3             20 spot                  no proof  24932145
# 4             20 spot  pet-nat & sparkling wine  24932165
# ...               ...                       ...       ...
# 52691       yucatasia       maya especialidades  24398826
# 52692       yucatasia       maya especialidades  24398828
# 52693       yucatasia       maya especialidades  24398828
# 52694       yucatasia       maya especialidades  24398828
# 52695       yucatasia       maya especialidades  24398828
#
#                                       menu_item  \
# 0                                "amaro" spritz
# 1                                 "gin & tonic"
# 2                                 amalfi spritz
# 3                                 amalfi spritz
# 4      athenais de beru, ‘love joy’, chardonnay
# ...                                         ...
# 52691                         49. cabeza de res
# 52692                                 50. pibes
# 52693                                 50. pibes
# 52694                                 50. pibes
# 52695                                 50. pibes
#
#                                         menu_description  \
# 0                                pathfinder amaro, tonic
# 1                                                 lyre's
# 2                                                 lyre's
# 3                                                 lyre's
# 4                                                    NaN
# ...                                                  ...
# 52691  beef tongue tossed in cabbage and radish serve...
# 52692  baked corn masa stuffed with chicken and pork ...
# 52693  baked corn masa stuffed with chicken and pork ...
# 52694  baked corn masa stuffed with chicken and pork ...
# 52695  baked corn masa stuffed with chicken and pork ...
#
#                                 ingredient_name  confidence  \
# 0                              pathfinder amaro        0.95
# 1                                           gin        0.80
# 2                                 amalfi spritz        0.95
# 3                                        lyre's        0.80
# 4      athenais de beru, 'love joy', chardonnay        0.90
# ...                                         ...         ...
# 52691                                  tortilla        0.90
# 52692                                   chicken        0.80
# 52693                                 corn masa        0.90
# 52694                                      pork        0.80
# 52695                                     salsa        0.70
#
#                    categories         address1           city  zip_code  \
# 0      New American|Wine Bars     3565 20th St  San Francisco   94110.0
# 1      New American|Wine Bars     3565 20th St  San Francisco   94110.0
# 2      New American|Wine Bars     3565 20th St  San Francisco   94110.0
# 3      New American|Wine Bars     3565 20th St  San Francisco   94110.0
# 4      New American|Wine Bars     3565 20th St  San Francisco   94110.0
# ...                       ...              ...            ...       ...
# 52691                 Mexican  2164 Mission St  San Francisco   94110.0
# 52692                 Mexican  2164 Mission St  San Francisco   94110.0
# 52693                 Mexican  2164 Mission St  San Francisco   94110.0
# 52694                 Mexican  2164 Mission St  San Francisco   94110.0
# 52695                 Mexican  2164 Mission St  San Francisco   94110.0
#
#       country state  rating  review_count price
# 0          US    CA     4.3         270.0    $$
# 1          US    CA     4.3         270.0    $$
# 2          US    CA     4.3         270.0    $$
# 3          US    CA     4.3         270.0    $$
# 4          US    CA     4.3         270.0    $$
# ...       ...   ...     ...           ...   ...
# 52691      US    CA     4.0          80.0     $
# 52692      US    CA     4.0          80.0     $
# 52693      US    CA     4.0          80.0     $
# 52694      US    CA     4.0          80.0     $
# 52695      US    CA     4.0          80.0     $
#
# [52696 rows x 16 columns]

# %%
Ingredients[Ingredients["address1"].isnull()]["restaurant_name"].unique()
# Out:
# array(['fort point valencia'], dtype=object)

# %%
Ingredients[Ingredients["zip_code"].isnull()]["restaurant_name"].unique()
# Out:
# array(['fort point valencia'], dtype=object)

# %% [markdown]
# > Only for fort point valencia we dont have address.

# %% [markdown]
# > We can use google maps api. However, we just have single missing entry here. That can be filled by manually searching.
# >
# > 742 Valencia St, San Francisco, CA 94110

# %%
restaurants_with_null_zip = rows_with_null_vals[Ingredients["zip_code"].isnull()]
unique_restaurants = restaurants_with_null_zip["restaurant_name"].unique()
rows_with_null_vals.loc[rows_with_null_vals["zip_code"].isnull(), "zip_code"] = 94110
rows_with_null_vals.loc[rows_with_null_vals["address1"].isnull(), "address1"] = "742 Valencia St"  
rows_with_null_vals.loc[rows_with_null_vals["city"].isnull(), "city"] = "San Francisco"  
rows_with_null_vals.loc[rows_with_null_vals["state"].isnull(), "state"] = "CA"  
rows_with_null_vals.loc[rows_with_null_vals["country"].isnull(), "country"] = "US"
# Out:
# /tmp/ipykernel_7997/3178223702.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   restaurants_with_null_zip = rows_with_null_vals[Ingredients["zip_code"].isnull()]

# %%
rows_with_null_vals.to_csv("rows_with_null_vals.csv")

# %%
rows_with_null_vals = pd.read_csv("rows_with_null_vals.csv").drop(["Unnamed: 0"], axis = 1)

# %%
item_ids_to_remove = rows_with_null_vals["item_id"].unique()

Ingredients_clean = Ingredients[~Ingredients["item_id"].isin(item_ids_to_remove)]

Ingredients_imputed = pd.concat([Ingredients_clean, rows_with_null_vals], ignore_index=True)

for col in Ingredients_imputed:
    Ingredients_imputed[col].fillna("Unknown", inplace = True)
# Out:
# /tmp/ipykernel_7997/1678889898.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Ingredients_imputed[col].fillna("Unknown", inplace = True)
# /tmp/ipykernel_7997/1678889898.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   Ingredients_imputed[col].fillna("Unknown", inplace = True)

# %%
Ingredients_imputed['menu_description'] = Ingredients_imputed['menu_description'].str.replace(r'[^\w\s]', '', regex=True).str.lower()
Ingredients_imputed['ingredient_name'] = Ingredients_imputed['ingredient_name'].str.replace(r'[^\w\s]', '', regex=True).str.lower()
Ingredients_imputed['restaurant_name'] = Ingredients_imputed['restaurant_name'].str.replace(r'[^\w\s]', '', regex=True).str.lower()
Ingredients_imputed['menu_item'] = Ingredients_imputed['menu_item'].str.replace(r'[^\w\s]', '', regex=True).str.lower()
Ingredients_imputed
# Out:
#        Unnamed: 0 restaurant_name      menu_category   item_id  \
# 0               0         20 spot           no proof  24932147
# 1               1         20 spot           no proof  24932146
# 2               2         20 spot           no proof  24932145
# 3               3         20 spot           no proof  24932145
# 4               4         20 spot           no proof  24932150
# ...           ...             ...                ...       ...
# 52668       52668          yasmin  syrian quesadilla  26086027
# 52669       52669          yasmin  syrian quesadilla  26086027
# 52670       52670          yasmin  syrian quesadilla  26086027
# 52671       52671          yasmin  syrian quesadilla  26086027
# 52672       52672          yasmin  syrian quesadilla  26086027
#
#                        menu_item        menu_description   ingredient_name  \
# 0                   amaro spritz  pathfinder amaro tonic  pathfinder amaro
# 1                     gin  tonic                   lyres               gin
# 2                  amalfi spritz                   lyres     amalfi spritz
# 3                  amalfi spritz                   lyres             lyres
# 4                   blood orange          san pellegrino      blood orange
# ...                          ...                     ...               ...
# 52668  syrian chicken quesadilla                     NaN         olive oil
# 52669  syrian chicken quesadilla                     NaN            onions
# 52670  syrian chicken quesadilla                     NaN           parsley
# 52671  syrian chicken quesadilla                     NaN        pita bread
# 52672  syrian chicken quesadilla                     NaN          tomatoes
#
#        confidence              categories         address1           city  \
# 0            0.95  New American|Wine Bars     3565 20th St  San Francisco
# 1            0.80  New American|Wine Bars     3565 20th St  San Francisco
# 2            0.95  New American|Wine Bars     3565 20th St  San Francisco
# 3            0.80  New American|Wine Bars     3565 20th St  San Francisco
# 4            0.90  New American|Wine Bars     3565 20th St  San Francisco
# ...           ...                     ...              ...            ...
# 52668        0.50           Mediterranean  799 Valencia St  San Francisco
# 52669        0.65           Mediterranean  799 Valencia St  San Francisco
# 52670        0.55           Mediterranean  799 Valencia St  San Francisco
# 52671        0.75           Mediterranean  799 Valencia St  San Francisco
# 52672        0.60           Mediterranean  799 Valencia St  San Francisco
#
#        zip_code country state  rating  review_count price
# 0       94110.0      US    CA     4.3         270.0    $$
# 1       94110.0      US    CA     4.3         270.0    $$
# 2       94110.0      US    CA     4.3         270.0    $$
# 3       94110.0      US    CA     4.3         270.0    $$
# 4       94110.0      US    CA     4.3         270.0    $$
# ...         ...     ...   ...     ...           ...   ...
# 52668   94110.0      US    CA     4.2         160.0    $$
# 52669   94110.0      US    CA     4.2         160.0    $$
# 52670   94110.0      US    CA     4.2         160.0    $$
# 52671   94110.0      US    CA     4.2         160.0    $$
# 52672   94110.0      US    CA     4.2         160.0    $$
#
# [52673 rows x 17 columns]

# %%
Ingredients_imputed.to_csv("Ingredients_imputed.csv")

# %%
local_filename = "Ingredients_imputed.csv"
s3.upload_file(local_filename, bucket_name, file_key)
print(f"File {local_filename} uploaded to bucket {bucket_name} with key {file_key}")
# Out:
# File Ingredients_imputed.csv uploaded to bucket menudatabucket with key Sample_Ingredients_File.csv

# %% [markdown]
# > Cleaned the data.
#
# > improved the descriptions by generating comprehensive descriptions on which embeddings would be created.
#
# > Finally pushed the data to S3 bucket.
